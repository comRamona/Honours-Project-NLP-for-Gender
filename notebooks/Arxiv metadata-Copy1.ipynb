# %%
from os import listdir
from os.path import isfile, join
from os import environ
import _pickle as pkl
from metadata import Gender
import pandas as pd
from itertools import chain
from _name_classification.nametools import process_str
from _name_classification.classifyname import NC
from _storage.storage import FileDir

# %%
train_dirpath = join(environ["ARXIV_DIR"], "data.arxiv.io", "data", "cs")
train_files = []
fd = FileDir()
for y in range(1994,2019):
    file_name = join(train_dirpath, str(y) + ".txt")
    train_files.append(file_name)

# %%
years_data = []
for file in train_files:
    data = pd.read_csv(file, sep = "\t", header = None, 
                    names = ["id", "categories", "authors", "title", "year", "abstract"])
    years_data.append(data)
df = pd.concat(years_data)

# %%
year_range = [1994,2019]
abstracts = []
for i in range(year_range[0],year_range[1]):
    year = df[df["year"] == i]
    for i in year.iterrows():
        abstracts.append(i[1].abstract)

# %%
fd.save_pickle(abstracts, "arxiv-abstracts")

# %%
from _storage.storage import FileDir
fd = FileDir()
known_f = fd.load_pickle("known_f_arxiv_n")
known_m = fd.load_pickle("known_m_arxiv_n")
known_m.remove("Lascarides, Alex")
known_f.add("Lascarides, Alex")

# %%
import re
def is_initials(name, sp=", "):
    
    fn = name.split(sp)
    if len(fn) < 2:
        return True
    fn = fn[1].strip()
    regex = re.compile(r"\w+\.", re.IGNORECASE)
    no_initials = regex.sub("", fn).strip()
    if len(no_initials) < 2:
        return True
    return False
        
def init_match(inits, name):
    inits = inits.replace("Dr.","")
    inits = inits.strip()
    if(len(inits) == 0):
        return 0
    name = name.strip()
    inits_split = inits.split(" ")
    name_split = name.split(" ")
    if len(inits_split) == len(name_split):
        match = True
        for idx, i in enumerate(inits_split):
            if i.strip()[0] != name_split[idx].strip()[0]:
                match = False
        if match == True:
            return 1 #confident match
    if inits[0] == name_split[0]:
        return 2 # maybe match
    inits_set = set()
    name_set = set()
    for letter in inits:
        if letter.isupper():
            inits_set.add(letter)
    for letter in name_set:
        if letter.isupper():
            name_set.add(letter)
    if inits_set == name_set:
        return 1 # confident match
    for letter in inits_set:
        if letter in name_set:
            return 3 # maybee
    return 0 #no match

from collections import defaultdict
male_last_names = defaultdict(list)
for name in known_m:
    if len(name.split(", ")) < 2:
        continue
    last, first = name.split(", ")
    male_last_names[last].append(first)
    
female_last_names = defaultdict(list)
for name in known_f:
    if len(name.split(", ")) < 2:
        continue
    last, first = name.split(", ")
    female_last_names[last].append(first)

def best_match(name):
    if len(name.split(", ")) < 2:
        return (None, None)
    last, first = name.split(", ")
    m = last in male_last_names
    f = last in female_last_names
    if m and not f:
        names = male_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                return (last + ", " + n, Gender.male)
       
    if f and not m:
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                return (last + ", " + n, Gender.male)
    if f and m:
        
        match_f = 0
        match_m = 0
        names = male_last_names[last]
        best_match = (None, None)
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_m):
                match_m = mtch
                best_match = (last + ", " + n, Gender.male)
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_f):
                match_f = mtch
                if mtch > match_m:
                    best_match = (last + ", " + n, Gender.female)
        if match_f > match_m:
            return best_match
        if match_m > match_f:
            return best_match
    return (None, None)

# %%
print(best_match("Reyle, U."))
# Out:
# ('Reyle, Uwe', <Gender.male: 0>)

# %%
df.set_index("id")
# Out:
#                                        categories  \
# id
# cmp-lg/9404001                       cmp-lg cs.CL
# cmp-lg/9404002                       cmp-lg cs.CL
# cmp-lg/9404003                       cmp-lg cs.CL
# cmp-lg/9404004                       cmp-lg cs.CL
# cmp-lg/9404005                       cmp-lg cs.CL
# cmp-lg/9404006                       cmp-lg cs.CL
# cmp-lg/9404007                       cmp-lg cs.CL
# cmp-lg/9404008                       cmp-lg cs.CL
# cmp-lg/9404009                       cmp-lg cs.CL
# cmp-lg/9404010                       cmp-lg cs.CL
# cmp-lg/9404011                       cmp-lg cs.CL
# cmp-lg/9405001                       cmp-lg cs.CL
# cmp-lg/9405002                       cmp-lg cs.CL
# cmp-lg/9405003                       cmp-lg cs.CL
# cmp-lg/9405004                       cmp-lg cs.CL
# cmp-lg/9405005                       cmp-lg cs.CL
# cmp-lg/9405006                       cmp-lg cs.CL
# cmp-lg/9405007                       cmp-lg cs.CL
# cmp-lg/9405008                       cmp-lg cs.CL
# cmp-lg/9405009                       cmp-lg cs.CL
# cmp-lg/9405010                       cmp-lg cs.CL
# cmp-lg/9405011                       cmp-lg cs.CL
# cmp-lg/9405012                       cmp-lg cs.CL
# cmp-lg/9405013                       cmp-lg cs.CL
# cmp-lg/9405014                       cmp-lg cs.CL
# cmp-lg/9405015                       cmp-lg cs.CL
# cmp-lg/9405016                       cmp-lg cs.CL
# cmp-lg/9405017                       cmp-lg cs.CL
# cmp-lg/9405018                       cmp-lg cs.CL
# cmp-lg/9405019                       cmp-lg cs.CL
# ...                                           ...
# 1801.0207300000002                          cs.CL
# 1801.02107                                  cs.CL
# 1801.02243                      cs.AI cs.CL cs.SI
# 1801.02581                                  cs.CL
# 1801.0266800000002              cs.HC cs.AI cs.CL
# 1801.02808                      cs.CL cs.IR cs.LG
# 1801.02832                      cs.IR cs.AI cs.CL
# 1801.02916                                  cs.CL
# 1801.0303199999998              cs.CL cs.IR cs.SI
# 1801.0325699999999                          cs.CL
# 1801.0333899999998                    cs.LG cs.CL
# 1801.0346                                   cs.CL
# 1801.0356199999999                          cs.CL
# 1801.03563                                  cs.CL
# 1801.0356399999998                          cs.CL
# 1801.03603                                  cs.CL
# 1801.03604          cs.AI cs.CL cs.CY cs.HC cs.MA
# 1801.03615                                  cs.CL
# 1801.03622          cs.CL cs.AI cs.CY cs.HC cs.MA
# 1801.03625          cs.CL cs.AI cs.CY cs.HC cs.MA
# 1801.03825                            cs.AI cs.CL
# 1801.0391100000002                    cs.CL cs.LG
# 1801.04017                                  cs.CL
# 1801.04354                cs.CL cs.CR cs.IR cs.LG
# 1801.0443300000002              cs.CL cs.CY cs.SI
# 1801.0447                                   cs.CL
# 1801.0455399999998              cs.IR cs.CL cs.LG
# 1801.04726                                  cs.CL
# 1801.0481300000001            cs.CL cs.LG stat.ML
# 1801.0487100000003                    cs.AI cs.CL
#
#                                                               authors  \
# id
# cmp-lg/9404001                      Schabes, Yves; Shieber, Stuart M.
# cmp-lg/9404002                                     Shieber, Stuart M.
# cmp-lg/9404003                                     Shieber, Stuart M.
# cmp-lg/9404004                                  Covington, Michael A.
# cmp-lg/9404005                                          Johnson, Mark
# cmp-lg/9404006                                  CHANDLER-BURNS, R. M.
# cmp-lg/9404007                       Bouma, Gosse; van Noord, Gertjan
# cmp-lg/9404008      Shieber, Stuart M.; Schabes, Yves; Pereira, Fe...
# cmp-lg/9404009      Dalrymple, Mary; Lamping, John; Pereira, Ferna...
# cmp-lg/9404010      Dalrymple, Mary; Lamping, John; Pereira, Ferna...
# cmp-lg/9404011                       van Noord, Gertjan; Bouma, Gosse
# cmp-lg/9405001            Dagan, Ido; Pereira, Fernando; Lee, Lillian
# cmp-lg/9405002                                         Kehler, Andrew
# cmp-lg/9405003                                      Hirschberg, Julia
# cmp-lg/9405004                                         Koenig, Esther
# cmp-lg/9405005                Magerman, David M.; Marcus, Mitchell P.
# cmp-lg/9405006                         Magerman, David M.; Weir, Carl
# cmp-lg/9405007      Black, Ezra; Jelinek, Fred; Lafferty, John; Ma...
# cmp-lg/9405008      Sproat, Richard; Shih, Chilin; Gale, William; ...
# cmp-lg/9405009                                     Magerman, David M.
# cmp-lg/9405010                                         Kehler, Andrew
# cmp-lg/9405011                Chu-Carroll, Jennifer; Carberry, Sandra
# cmp-lg/9405012                                              Hong, Tao
# cmp-lg/9405013                                     Edmonds, Philip G.
# cmp-lg/9405014                                       Litman, Diane J.
# cmp-lg/9405015               Passonneau, Rebecca J.; Litman, Diane J.
# cmp-lg/9405016                      Stolcke, Andreas; Segal, Jonathan
# cmp-lg/9405017                Stolcke, Andreas; Omohundro, Stephen M.
# cmp-lg/9405018                                      Daelemans, Walter
# cmp-lg/9405019                          Murata, Masaki; Nagao, Makoto
# ...                                                               ...
# 1801.0207300000002       Jurczyk, Tomasz; Deshmane, Amit; Choi, Jinho
# 1801.02107                                              Kashefi, Omid
# 1801.02243                             Xiao, Catherine; Chen, Wanfeng
# 1801.02581                              Mandal, Soumil; Das, Dipankar
# 1801.0266800000002  Huang, Ting-Hao 'Kenneth'; Chang, Joseph Chee;...
# 1801.02808                       Chen, Zhiyuan; Ma, Nianzu; Liu, Bing
# 1801.02832                           Galkó, Ferenc; Eickhoff, Carsten
# 1801.02916                         Vodolán, Miroslav; Jurčíček, Filip
# 1801.0303199999998   Dey, Kuntal; Shrivastava, Ritvik; Kaushik, Saroj
# 1801.0325699999999  Wang, Longyue; Tu, Zhaopeng; Shi, Shuming; Zha...
# 1801.0333899999998  Kreuk, Felix; Adi, Yossi; Cisse, Moustapha; Ke...
# 1801.0346           Criscuolo, Marcelo; Fonseca, Erick Rocha; Aluí...
# 1801.0356199999999    Tupper, Paul; Smolensky, Paul; Cho, Pyeong Whan
# 1801.03563             Dowell, Nia; Nixon, Tristian; Graesser, Arthur
# 1801.0356399999998                                      Kashefi, Omid
# 1801.03603          He, Zhengqiu; Chen, Wenliang; Li, Zhenghua; Zh...
# 1801.03604          Ram, Ashwin; Prasad, Rohit; Khatri, Chandra; V...
# 1801.03615             Song, Kai; Zhang, Yue; Zhang, Min; Luo, Weihua
# 1801.03622          Guo, Fenfei; Metallinou, Angeliki; Khatri, Cha...
# 1801.03625          Venkatesh, Anu; Khatri, Chandra; Ram, Ashwin; ...
# 1801.03825          Dubey, Mohnish; Banerjee, Debayan; Chaudhuri, ...
# 1801.0391100000002       Garg, Sahil; Steeg, Greg Ver; Galstyan, Aram
# 1801.04017          Kernot, David; Bossomaier, Terry; Bradbury, Roger
# 1801.04354          Gao, Ji; Lanchantin, Jack; Soffa, Mary Lou; Qi...
# 1801.0443300000002  Pitsilis, Georgios K.; Ramampiaro, Heri; Langs...
# 1801.0447           Bennani-Smires, Kamil; Musat, Claudiu; Jaggi, ...
# 1801.0455399999998  Ferreira, Charles Henrique Porto; de Medeiros,...
# 1801.04726                 Zhou, Mantong; Huang, Minlie; Zhu, Xiaoyan
# 1801.0481300000001                                        Hoang, Quan
# 1801.0487100000003  Shah, Pararth; Hakkani-Tür, Dilek; Tür, Gokhan...
#
#                                                                 title  year  \
# id
# cmp-lg/9404001      An Alternative Conception of Tree-Adjoining De...  1994
# cmp-lg/9404002                  Lessons from a Restricted Turing Test  1994
# cmp-lg/9404003      Restricting the Weak-Generative Capacity of Sy...  1994
# cmp-lg/9404004      An Empirically Motivated Reinterpretation of D...  1994
# cmp-lg/9404005            Memoization in Constraint Logic Programming  1994
# cmp-lg/9404006      SPANISH 1992 ( S92 ) : corpus-based analysis o...  1994
# cmp-lg/9404007                    Constraint-Based Categorial Grammar  1994
# cmp-lg/9404008      Principles and Implementation of Deductive Par...  1994
# cmp-lg/9404009           A Deductive Account of Quantification in LFG  1994
# cmp-lg/9404010      Intensional Verbs Without Type-Raising or Lexi...  1994
# cmp-lg/9404011           Adjuncts and the Processing of Lexical Rules  1994
# cmp-lg/9405001      Similarity-Based Estimation of Word Cooccurren...  1994
# cmp-lg/9405002      Temporal Relations : Reference or Discourse Co...  1994
# cmp-lg/9405003      Some Bibliographical References on Intonation ...  1994
# cmp-lg/9405004                       Syntactic-Head-Driven Generation  1994
# cmp-lg/9405005                   Pearl : A Probabilistic Chart Parser  1994
# cmp-lg/9405006      Efficiency , Robustness , and Accuracy in Pick...  1994
# cmp-lg/9405007      Towards History-based Grammars : Using Richer ...  1994
# cmp-lg/9405008      A Stochastic Finite-State Word-Segmentation Al...  1994
# cmp-lg/9405009      Natural Language Parsing as Statistical Patter...  1994
# cmp-lg/9405010      Common Topics and Coherent Situations : Interp...  1994
# cmp-lg/9405011      A Plan-Based Model for Response Generation in ...  1994
# cmp-lg/9405012      Integration Of Visual Inter-word Constraints A...  1994
# cmp-lg/9405013      Collaboration on reference to objects that are...  1994
# cmp-lg/9405014      Classifying Cue Phrases in Text and Speech Usi...  1994
# cmp-lg/9405015      Intention-based Segmentation : Human Reliabili...  1994
# cmp-lg/9405016      Precise n-gram Probabilities from Stochastic C...  1994
# cmp-lg/9405017      Best-first Model Merging for Hidden Markov Mod...  1994
# cmp-lg/9405018        Memory-Based Lexical Acquisition and Processing  1994
# cmp-lg/9405019      Determination of referential property and numb...  1994
# ...                                                               ...   ...
# 1801.0207300000002  Analysis of Wikipedia-based Corpora for Questi...  2018
# 1801.02107            MIZAN : A Large Persian-English Parallel Corpus  2018
# 1801.02243          Trading the Twitter Sentiment with Reinforceme...  2018
# 1801.02581          Analyzing Roles of Classifiers and Code-Mixed ...  2018
# 1801.0266800000002  Evorus : A Crowd-powered Conversational Assist...  2018
# 1801.02808             Lifelong Learning for Sentiment Classification  2018
# 1801.02832          Biomedical Question Answering via Weighted Neu...  2018
# 1801.02916          Denotation Extraction for Interactive Learning...  2018
# 1801.0303199999998  Topical Stance Detection for Twitter : A Two-P...  2018
# 1801.0325699999999  Translating Pro-Drop Languages with Reconstruc...  2018
# 1801.0333899999998  Fooling End-to-end Speaker Verification by Adv...  2018
# 1801.0346           MilkQA : a Dataset of Consumer Questions for t...  2018
# 1801.0356199999999  Discrete symbolic optimization and Boltzmann s...  2018
# 1801.03563          Group Communication Analysis : A Computational...  2018
# 1801.0356399999998              Unsupervised Part-of-Speech Induction  2018
# 1801.03603          SEE : Syntax-aware Entity Embedding for Neural...  2018
# 1801.03604          Conversational AI : The Science Behind the Ale...  2018
# 1801.03615          Improved English to Russian Translation by Neu...  2018
# 1801.03622             Topic-based Evaluation for Conversational Bots  2018
# 1801.03625          On Evaluating and Comparing Conversational Agents  2018
# 1801.03825          EARL : Joint Entity and Relation Linking for Q...  2018
# 1801.0391100000002  Stochastic Learning of Nonstationary Kernels f...  2018
# 1801.04017          Did William Shakespeare and Thomas Kyd Write E...  2018
# 1801.04354          Black-box Generation of Adversarial Text Seque...  2018
# 1801.0443300000002  Detecting Offensive Language in Tweets Using D...  2018
# 1801.0447           EmbedRank : Unsupervised Keyphrase Extraction ...  2018
# 1801.0455399999998  DCDistance : A Supervised Text Document Featur...  2018
# 1801.04726          An Interpretable Reasoning Network for Multi-R...  2018
# 1801.0481300000001    Predicting Movie Genres Based on Plot Summaries  2018
# 1801.0487100000003  Building a Conversational Agent Overnight with...  2018
#
#                                                              abstract
# id
# cmp-lg/9404001      The precise formulation of derivation for tree...
# cmp-lg/9404002      We report on the recent Loebner prize competit...
# cmp-lg/9404003      The formalism of synchronous tree-adjoining gr...
# cmp-lg/9404004      Dependency grammar is usually interpreted as e...
# cmp-lg/9404005      This paper shows how to apply memoization ( ca...
# cmp-lg/9404006      S92 research was begun in 1987 to analyze word...
# cmp-lg/9404007      We propose a generalization of Categorial Gram...
# cmp-lg/9404008      We present a system for generating parsers bas...
# cmp-lg/9404009      The relationship between Lexical-Functional Gr...
# cmp-lg/9404010      We present an analysis of the semantic interpr...
# cmp-lg/9404011      The standard HPSG analysis of Germanic verb cl...
# cmp-lg/9405001      In many applications of natural language proce...
# cmp-lg/9405002      The temporal relations that hold between event...
# cmp-lg/9405003      A by-no-means-complete collection of reference...
# cmp-lg/9405004      The previously proposed semantic-head-driven g...
# cmp-lg/9405005      This paper describes a natural language parsin...
# cmp-lg/9405006      This paper describes Picky , a probabilistic a...
# cmp-lg/9405007      We describe a generative probabilistic model o...
# cmp-lg/9405008      We present a stochastic finite-state model for...
# cmp-lg/9405009      Traditional natural language parsers are based...
# cmp-lg/9405010      It is claimed that a variety of facts concerni...
# cmp-lg/9405011      This paper presents a plan-based architecture ...
# cmp-lg/9405012      Degraded text recognition is a difficult task ...
# cmp-lg/9405013      In conversation , a person sometimes has to re...
# cmp-lg/9405014      Cue phrases may be used in a discourse sense t...
# cmp-lg/9405015      Certain spans of utterances in a discourse , r...
# cmp-lg/9405016      We present an algorithm for computing n-gram p...
# cmp-lg/9405017      This report describes a new technique for indu...
# cmp-lg/9405018      Current approaches to computational lexicology...
# cmp-lg/9405019      When translating Japanese nouns into English ,...
# ...                                                               ...
# 1801.0207300000002  This paper gives comprehensive analyses of cor...
# 1801.02107          One of the most major and essential tasks in n...
# 1801.02243          This paper is to explore the possibility to us...
# 1801.02581          Multilingual speakers often switch between lan...
# 1801.0266800000002  Crowd-powered conversational assistants have b...
# 1801.02808          This paper proposes a novel lifelong learning ...
# 1801.02832          The amount of publicly available biomedical li...
# 1801.02916          This paper presents a novel task using real us...
# 1801.0303199999998  The topical stance detection problem addresses...
# 1801.0325699999999  Pronouns are frequently omitted in pro-drop la...
# 1801.0333899999998  Automatic speaker verification systems are inc...
# 1801.0346           We introduce MilkQA , a question answering dat...
# 1801.0356199999999  Gradient Symbolic Computation is proposed as a...
# 1801.03563          Roles are one of the most important concepts i...
# 1801.0356399999998  Part-of-Speech ( POS ) tagging is an old and f...
# 1801.03603          Distant supervised relation extraction is an e...
# 1801.03604          Conversational agents are exploding in popular...
# 1801.03615          Neural machine translation ( NMT ) suffers a p...
# 1801.03622          Dialog evaluation is a challenging problem , e...
# 1801.03625          Conversational agents are exploding in popular...
# 1801.03825          In order to answer natural language questions ...
# 1801.0391100000002  Natural language processing often involves com...
# 1801.04017          William Shakespeare is believed to be a signif...
# 1801.04354          Although various techniques have been proposed...
# 1801.0443300000002  This paper addresses the important problem of ...
# 1801.0447           Keyphrase extraction is the task of automatica...
# 1801.0455399999998  Text Mining is a field that aims at extracting...
# 1801.04726          Multi-relation Question Answering is a challen...
# 1801.0481300000001  This project explores several Machine Learning...
# 1801.0487100000003  We propose Machines Talking To Machines ( M2M ...
#
# [7934 rows x 5 columns]

# %%
#gender_df.set_index("id")
gender_df
# Out:
# Empty DataFrame
# Columns: [id, authors, genders, title, year]
# Index: []

# %%
all_authors = df["id"].values
all_authors
# Out:
# array(['cmp-lg/9404001', 'cmp-lg/9404002', 'cmp-lg/9404003', ...,
#        1801.04726, 1801.0481300000001, 1801.0487100000003], dtype=object)

# %%
c = ["id", "authors", "genders", "title", "year"]
gender_df = pd.DataFrame(columns=c)
k = 0
for row in df.iterrows():
    new_entry = dict()
    for col in ["id", "authors", "title", "year", "abstract"]:
        new_entry[col] = row[1][col]
    authors = row[1]["authors"].split("; ")
    genders = []
    correct_authors = []
    for a in authors:
        if is_initials(a):
            #print(a)
            #print(best_match(a))
            best_m, g = best_match(a)
            if best_m != None:
                correct_authors.append(best_m)
                genders.append(g)
                k += 1
                continue
                #print(a, best_m)
        correct_authors.append(a)
        if(a in known_m):
            genders.append(Gender.male)
        elif a in known_f:
            genders.append(Gender.female)
        else:
            genders.append(Gender.unknown)
    if len(correct_authors) != len(genders):
        print("error")
    new_entry["authors"] = correct_authors
    new_entry["genders"] = genders
    gender_df = gender_df.append(new_entry, ignore_index=True)
gender_df.set_index("id")
print(k)
# Out:
# 226

# %%
gender_df
# Out:
#                   id                                            authors  \
# 0     cmp-lg/9404001                [Schabes, Yves, Shieber, Stuart M.]
# 1     cmp-lg/9404002                               [Shieber, Stuart M.]
# 2     cmp-lg/9404003                               [Shieber, Stuart M.]
# 3     cmp-lg/9404004                            [Covington, Michael A.]
# 4     cmp-lg/9404005                                    [Johnson, Mark]
# 5     cmp-lg/9404006                            [CHANDLER-BURNS, R. M.]
# 6     cmp-lg/9404007                 [Bouma, Gosse, van Noord, Gertjan]
# 7     cmp-lg/9404008  [Shieber, Stuart M., Schabes, Yves, Pereira, F...
# 8     cmp-lg/9404009  [Dalrymple, Mary, Lamping, John, Pereira, Fern...
# 9     cmp-lg/9404010  [Dalrymple, Mary, Lamping, John, Pereira, Fern...
# 10    cmp-lg/9404011                 [van Noord, Gertjan, Bouma, Gosse]
# 11    cmp-lg/9405001      [Dagan, Ido, Pereira, Fernando, Lee, Lillian]
# 12    cmp-lg/9405002                                   [Kehler, Andrew]
# 13    cmp-lg/9405003                                [Hirschberg, Julia]
# 14    cmp-lg/9405004                                   [Koenig, Esther]
# 15    cmp-lg/9405005          [Magerman, David M., Marcus, Mitchell P.]
# 16    cmp-lg/9405006                   [Magerman, David M., Weir, Carl]
# 17    cmp-lg/9405007  [Black, Ezra, Jelinek, Fred, Lafferty, John, M...
# 18    cmp-lg/9405008  [Sproat, Richard, Shih, Chilin, Gale, William,...
# 19    cmp-lg/9405009                               [Magerman, David M.]
# 20    cmp-lg/9405010                                   [Kehler, Andrew]
# 21    cmp-lg/9405011          [Chu-Carroll, Jennifer, Carberry, Sandra]
# 22    cmp-lg/9405012                                        [Hong, Tao]
# 23    cmp-lg/9405013                               [Edmonds, Philip G.]
# 24    cmp-lg/9405014                                 [Litman, Diane J.]
# 25    cmp-lg/9405015         [Passonneau, Rebecca J., Litman, Diane J.]
# 26    cmp-lg/9405016                [Stolcke, Andreas, Segal, Jonathan]
# 27    cmp-lg/9405017          [Stolcke, Andreas, Omohundro, Stephen M.]
# 28    cmp-lg/9405018                                [Daelemans, Walter]
# 29    cmp-lg/9405019                    [Murata, Masaki, Nagao, Makoto]
# ...              ...                                                ...
# 7904         1801.02     [Jurczyk, Tomasz, Deshmane, Amit, Choi, Jinho]
# 7905         1801.02                                    [Kashefi, Omid]
# 7906         1801.02                   [Xiao, Catherine, Chen, Wanfeng]
# 7907         1801.03                    [Mandal, Soumil, Das, Dipankar]
# 7908         1801.03  [Huang, Ting-Hao 'Kenneth', Chang, Joseph Chee...
# 7909         1801.03             [Chen, Zhiyuan, Ma, Nianzu, Liu, Bing]
# 7910         1801.03                 [Galkó, Ferenc, Eickhoff, Carsten]
# 7911         1801.03               [Vodolán, Miroslav, Jurčíček, Filip]
# 7912         1801.03  [Dey, Kuntal, Shrivastava, Ritvik, Kaushik, Sa...
# 7913         1801.03  [Wang, Longyue, Tu, Zhaopeng, Shi, Shuming, Zh...
# 7914         1801.03  [Kreuk, Felix, Adi, Yossi, Cisse, Moustapha, K...
# 7915         1801.03  [Criscuolo, Marcelo, Fonseca, Erick Rocha, Alu...
# 7916         1801.04  [Tupper, Paul, Smolensky, Paul, Cho, Pyeong Whan]
# 7917         1801.04   [Dowell, Nia, Nixon, Tristian, Graesser, Arthur]
# 7918         1801.04                                    [Kashefi, Omid]
# 7919         1801.04  [He, Zhengqiu, Chen, Wenliang, Li, Zhenghua, Z...
# 7920         1801.04  [Ram, Ashwin, Prasad, Rohit, Khatri, Chandra, ...
# 7921         1801.04   [Song, Kai, Zhang, Yue, Zhang, Min, Luo, Weihua]
# 7922         1801.04  [Guo, Fenfei, Metallinou, Angeliki, Khatri, Ch...
# 7923         1801.04  [Venkatesh, Anu, Khatri, Chandra, Ram, Ashwin,...
# 7924         1801.04  [Dubey, Mohnish, Banerjee, Debayan, Chaudhuri,...
# 7925         1801.04     [Garg, Sahil, Steeg, Greg Ver, Galstyan, Aram]
# 7926         1801.04  [Kernot, David, Bossomaier, Terry, Bradbury, R...
# 7927         1801.04  [Gao, Ji, Lanchantin, Jack, Soffa, Mary Lou, Q...
# 7928         1801.04  [Pitsilis, Georgios K., Ramampiaro, Heri, Lang...
# 7929         1801.04  [Bennani-Smires, Kamil, Musat, Claudiu, Jaggi,...
# 7930         1801.05  [Ferreira, Charles Henrique Porto, de Medeiros...
# 7931         1801.05       [Zhou, Mantong, Huang, Minlie, Zhu, Xiaoyan]
# 7932         1801.05                                      [Hoang, Quan]
# 7933         1801.05  [Shah, Pararth, Hakkani-Tür, Dilek, Tür, Gokha...
#
#                                                 genders  \
# 0                            [Gender.male, Gender.male]
# 1                                         [Gender.male]
# 2                                         [Gender.male]
# 3                                         [Gender.male]
# 4                                         [Gender.male]
# 5                                      [Gender.unknown]
# 6                            [Gender.male, Gender.male]
# 7               [Gender.male, Gender.male, Gender.male]
# 8     [Gender.female, Gender.male, Gender.male, Gend...
# 9     [Gender.female, Gender.male, Gender.male, Gend...
# 10                           [Gender.male, Gender.male]
# 11            [Gender.male, Gender.male, Gender.female]
# 12                                        [Gender.male]
# 13                                      [Gender.female]
# 14                                      [Gender.female]
# 15                           [Gender.male, Gender.male]
# 16                           [Gender.male, Gender.male]
# 17    [Gender.male, Gender.male, Gender.male, Gender...
# 18    [Gender.male, Gender.female, Gender.male, Gend...
# 19                                        [Gender.male]
# 20                                        [Gender.male]
# 21                       [Gender.female, Gender.female]
# 22                                      [Gender.female]
# 23                                        [Gender.male]
# 24                                      [Gender.female]
# 25                       [Gender.female, Gender.female]
# 26                           [Gender.male, Gender.male]
# 27                           [Gender.male, Gender.male]
# 28                                        [Gender.male]
# 29                           [Gender.male, Gender.male]
# ...                                                 ...
# 7904            [Gender.male, Gender.male, Gender.male]
# 7905                                      [Gender.male]
# 7906                       [Gender.female, Gender.male]
# 7907                         [Gender.male, Gender.male]
# 7908         [Gender.unknown, Gender.male, Gender.male]
# 7909          [Gender.male, Gender.female, Gender.male]
# 7910                         [Gender.male, Gender.male]
# 7911                         [Gender.male, Gender.male]
# 7912          [Gender.female, Gender.male, Gender.male]
# 7913  [Gender.male, Gender.female, Gender.female, Ge...
# 7914  [Gender.male, Gender.male, Gender.male, Gender...
# 7915  [Gender.male, Gender.male, Gender.female, Gend...
# 7916         [Gender.male, Gender.male, Gender.unknown]
# 7917          [Gender.female, Gender.male, Gender.male]
# 7918                                      [Gender.male]
# 7919  [Gender.unknown, Gender.male, Gender.male, Gen...
# 7920  [Gender.male, Gender.male, Gender.female, Gend...
# 7921  [Gender.male, Gender.male, Gender.female, Gend...
# 7922  [Gender.unknown, Gender.female, Gender.female,...
# 7923  [Gender.female, Gender.female, Gender.male, Ge...
# 7924  [Gender.male, Gender.male, Gender.male, Gender...
# 7925            [Gender.male, Gender.male, Gender.male]
# 7926            [Gender.male, Gender.male, Gender.male]
# 7927  [Gender.unknown, Gender.male, Gender.female, G...
# 7928            [Gender.male, Gender.male, Gender.male]
# 7929  [Gender.male, Gender.male, Gender.male, Gender...
# 7930          [Gender.male, Gender.female, Gender.male]
# 7931       [Gender.unknown, Gender.male, Gender.female]
# 7932                                      [Gender.male]
# 7933  [Gender.male, Gender.female, Gender.male, Gend...
#
#                                                   title  year  \
# 0     An Alternative Conception of Tree-Adjoining De...  1994
# 1                 Lessons from a Restricted Turing Test  1994
# 2     Restricting the Weak-Generative Capacity of Sy...  1994
# 3     An Empirically Motivated Reinterpretation of D...  1994
# 4           Memoization in Constraint Logic Programming  1994
# 5     SPANISH 1992 ( S92 ) : corpus-based analysis o...  1994
# 6                   Constraint-Based Categorial Grammar  1994
# 7     Principles and Implementation of Deductive Par...  1994
# 8          A Deductive Account of Quantification in LFG  1994
# 9     Intensional Verbs Without Type-Raising or Lexi...  1994
# 10         Adjuncts and the Processing of Lexical Rules  1994
# 11    Similarity-Based Estimation of Word Cooccurren...  1994
# 12    Temporal Relations : Reference or Discourse Co...  1994
# 13    Some Bibliographical References on Intonation ...  1994
# 14                     Syntactic-Head-Driven Generation  1994
# 15                 Pearl : A Probabilistic Chart Parser  1994
# 16    Efficiency , Robustness , and Accuracy in Pick...  1994
# 17    Towards History-based Grammars : Using Richer ...  1994
# 18    A Stochastic Finite-State Word-Segmentation Al...  1994
# 19    Natural Language Parsing as Statistical Patter...  1994
# 20    Common Topics and Coherent Situations : Interp...  1994
# 21    A Plan-Based Model for Response Generation in ...  1994
# 22    Integration Of Visual Inter-word Constraints A...  1994
# 23    Collaboration on reference to objects that are...  1994
# 24    Classifying Cue Phrases in Text and Speech Usi...  1994
# 25    Intention-based Segmentation : Human Reliabili...  1994
# 26    Precise n-gram Probabilities from Stochastic C...  1994
# 27    Best-first Model Merging for Hidden Markov Mod...  1994
# 28      Memory-Based Lexical Acquisition and Processing  1994
# 29    Determination of referential property and numb...  1994
# ...                                                 ...   ...
# 7904  Analysis of Wikipedia-based Corpora for Questi...  2018
# 7905    MIZAN : A Large Persian-English Parallel Corpus  2018
# 7906  Trading the Twitter Sentiment with Reinforceme...  2018
# 7907  Analyzing Roles of Classifiers and Code-Mixed ...  2018
# 7908  Evorus : A Crowd-powered Conversational Assist...  2018
# 7909     Lifelong Learning for Sentiment Classification  2018
# 7910  Biomedical Question Answering via Weighted Neu...  2018
# 7911  Denotation Extraction for Interactive Learning...  2018
# 7912  Topical Stance Detection for Twitter : A Two-P...  2018
# 7913  Translating Pro-Drop Languages with Reconstruc...  2018
# 7914  Fooling End-to-end Speaker Verification by Adv...  2018
# 7915  MilkQA : a Dataset of Consumer Questions for t...  2018
# 7916  Discrete symbolic optimization and Boltzmann s...  2018
# 7917  Group Communication Analysis : A Computational...  2018
# 7918              Unsupervised Part-of-Speech Induction  2018
# 7919  SEE : Syntax-aware Entity Embedding for Neural...  2018
# 7920  Conversational AI : The Science Behind the Ale...  2018
# 7921  Improved English to Russian Translation by Neu...  2018
# 7922     Topic-based Evaluation for Conversational Bots  2018
# 7923  On Evaluating and Comparing Conversational Agents  2018
# 7924  EARL : Joint Entity and Relation Linking for Q...  2018
# 7925  Stochastic Learning of Nonstationary Kernels f...  2018
# 7926  Did William Shakespeare and Thomas Kyd Write E...  2018
# 7927  Black-box Generation of Adversarial Text Seque...  2018
# 7928  Detecting Offensive Language in Tweets Using D...  2018
# 7929  EmbedRank : Unsupervised Keyphrase Extraction ...  2018
# 7930  DCDistance : A Supervised Text Document Featur...  2018
# 7931  An Interpretable Reasoning Network for Multi-R...  2018
# 7932    Predicting Movie Genres Based on Plot Summaries  2018
# 7933  Building a Conversational Agent Overnight with...  2018
#
#                                                abstract
# 0     The precise formulation of derivation for tree...
# 1     We report on the recent Loebner prize competit...
# 2     The formalism of synchronous tree-adjoining gr...
# 3     Dependency grammar is usually interpreted as e...
# 4     This paper shows how to apply memoization ( ca...
# 5     S92 research was begun in 1987 to analyze word...
# 6     We propose a generalization of Categorial Gram...
# 7     We present a system for generating parsers bas...
# 8     The relationship between Lexical-Functional Gr...
# 9     We present an analysis of the semantic interpr...
# 10    The standard HPSG analysis of Germanic verb cl...
# 11    In many applications of natural language proce...
# 12    The temporal relations that hold between event...
# 13    A by-no-means-complete collection of reference...
# 14    The previously proposed semantic-head-driven g...
# 15    This paper describes a natural language parsin...
# 16    This paper describes Picky , a probabilistic a...
# 17    We describe a generative probabilistic model o...
# 18    We present a stochastic finite-state model for...
# 19    Traditional natural language parsers are based...
# 20    It is claimed that a variety of facts concerni...
# 21    This paper presents a plan-based architecture ...
# 22    Degraded text recognition is a difficult task ...
# 23    In conversation , a person sometimes has to re...
# 24    Cue phrases may be used in a discourse sense t...
# 25    Certain spans of utterances in a discourse , r...
# 26    We present an algorithm for computing n-gram p...
# 27    This report describes a new technique for indu...
# 28    Current approaches to computational lexicology...
# 29    When translating Japanese nouns into English ,...
# ...                                                 ...
# 7904  This paper gives comprehensive analyses of cor...
# 7905  One of the most major and essential tasks in n...
# 7906  This paper is to explore the possibility to us...
# 7907  Multilingual speakers often switch between lan...
# 7908  Crowd-powered conversational assistants have b...
# 7909  This paper proposes a novel lifelong learning ...
# 7910  The amount of publicly available biomedical li...
# 7911  This paper presents a novel task using real us...
# 7912  The topical stance detection problem addresses...
# 7913  Pronouns are frequently omitted in pro-drop la...
# 7914  Automatic speaker verification systems are inc...
# 7915  We introduce MilkQA , a question answering dat...
# 7916  Gradient Symbolic Computation is proposed as a...
# 7917  Roles are one of the most important concepts i...
# 7918  Part-of-Speech ( POS ) tagging is an old and f...
# 7919  Distant supervised relation extraction is an e...
# 7920  Conversational agents are exploding in popular...
# 7921  Neural machine translation ( NMT ) suffers a p...
# 7922  Dialog evaluation is a challenging problem , e...
# 7923  Conversational agents are exploding in popular...
# 7924  In order to answer natural language questions ...
# 7925  Natural language processing often involves com...
# 7926  William Shakespeare is believed to be a signif...
# 7927  Although various techniques have been proposed...
# 7928  This paper addresses the important problem of ...
# 7929  Keyphrase extraction is the task of automatica...
# 7930  Text Mining is a field that aims at extracting...
# 7931  Multi-relation Question Answering is a challen...
# 7932  This project explores several Machine Learning...
# 7933  We propose Machines Talking To Machines ( M2M ...
#
# [7934 rows x 6 columns]

# %%
fd.save_pickle(gender_df, "arxivdf")

# %%
my_new_unk_n_papers = defaultdict(int)
n_papers = defaultdict(int)
pp = dict()
all_auths = set()
for row in gender_df.iterrows():
    genders = row[1]["genders"]
    authors = row[1]["authors"]
    paper = row[1]["title"]
    for i,g in enumerate(genders):
        n_papers[authors[i]] += 1
        if g == Gender.unknown:
            my_new_unk_n_papers[authors[i]] += 1
            pp[authors[i]] = paper
    for a in authors:
        all_auths.add(a)

# %%
my_new_unk = dict()
for u, n in my_new_unk_n_papers.items():
    if n >= 1:
        my_new_unk[u] = pp[u]

# %%
my_new_unk
# Out:
# {'CHANDLER-BURNS, R. M.': 'SPANISH 1992 ( S92 ) : corpus-based analysis of present-day Spanish for medical purposes',
#  'Smith, F. J.': 'Improving Statistical Language Model Performance with Automatically Generated Word Hierarchies',
#  'Chen, Kuang-hua': 'Automatic Identification of Subjects for Textual Documents in Digital Libraries',
#  'Srinivas, B.': 'Heuristics and Parse Ranking',
#  'Kim, Geunbae Lee Jong-Hyeok Lee Kyunghee': 'Phoneme-level speech and natural language intergration for agglutinative languages',
#  'Schubert, Lenhart': 'Knowledge Representation for Lexical Semantics : Is Standard First Order Logic Enough ?',
#  'Vagelatos, A.': 'An electronic dictionary as a basis for NLP tools : The Greek case',
#  'Triantopoulou, T.': 'Utilization of a Lexicon for Spelling Correction in Modern Greek',
#  'Tsalidis, C.': 'Utilization of a Lexicon for Spelling Correction in Modern Greek',
#  'Christodoulakis, D.': 'Utilization of a Lexicon for Spelling Correction in Modern Greek',
#  'Lee, Geunbae': 'Unlimited Vocabulary Grapheme to Phoneme Conversion for Korean TTS',
#  'Ritchie, G. D.': 'Time , Tense and Aspect in Natural Language Database Interfaces',
#  'Thanisch, P.': 'Time , Tense and Aspect in Natural Language Database Interfaces',
#  'Aduriz, I.': 'Different Issues in the Design of a Lemmatizer/Tagger for Basque',
#  'Arriola, J. M.': 'Different Issues in the Design of a Lemmatizer/Tagger for Basque',
#  'Ezeiza, N.': 'Different Issues in the Design of a Lemmatizer/Tagger for Basque',
#  'Gojenola, K.': 'Towards a single proposal is spelling correction',
#  'Collet, P.': 'MAXIMUM LIKELIHOOD AND MINIMUM ENTROPY IDENTIFICATION OF GRAMMARS',
#  'Galves, A.': 'MAXIMUM LIKELIHOOD AND MINIMUM ENTROPY IDENTIFICATION OF GRAMMARS',
#  'Shin, Sanghyun': 'TAKTAG : Two-phase learning method for hybrid statistical/rule-based part-of-speech disambiguation',
#  'Della Pietra, S.': 'Inducing Features of Random Fields',
#  'Della Pietra, V.': 'Inducing Features of Random Fields',
#  'Zhai, Chengxiang': 'Fast Statistical Parsing of Noun Phrases for Document Indexing',
#  'Eckert, W.': 'Towards Understanding Spontaneous Speech : Word Accuracy vs. Concept Accuracy',
#  'Gransden, I. R.': 'Clustered Language Models with Context-Equivalent States',
#  'Di Eugenio, ': 'Learning Micro-Planning Rules for Preventative Expressions',
#  'Barbara': 'Learning Micro-Planning Rules for Preventative Expressions',
#  'Bosch, Antal van den': 'Unraveling reported dreams with text analytics',
#  'Kim, Sangeok': 'Integrating HMM-Based Speech Recognition With Direct Manipulation In A Multimodal Korean Natural Language Interface',
#  'Eklund, ': 'Translation Methodology in the Spoken Language Translator : An Evaluation',
#  'Kirchmeier-Andersen, ': 'Translation Methodology in the Spoken Language Translator : An Evaluation',
#  'Sabine': 'Translation Methodology in the Spoken Language Translator : An Evaluation',
#  'Braun, C.': 'An Information Extraction Core System for Real World German Text Processing',
#  'Calder, Jo': 'Generating Multilingual Personalized Descriptions of Museum Exhibits - The M-PIRO Project',
#  'Orsucci, F.': 'Orthographic Structuring of Human Speech and Texts : Linguistic Application of Recurrence Quantification Analysis',
#  'Walter, K.': 'Orthographic Structuring of Human Speech and Texts : Linguistic Application of Recurrence Quantification Analysis',
#  'Giuliani, A.': 'Orthographic Structuring of Human Speech and Texts : Linguistic Application of Recurrence Quantification Analysis',
#  'Webber,, C. L.': 'Orthographic Structuring of Human Speech and Texts : Linguistic Application of Recurrence Quantification Analysis',
#  'Zbilut, J. P.': 'Orthographic Structuring of Human Speech and Texts : Linguistic Application of Recurrence Quantification Analysis',
#  'da Costa, N. C. A.': 'On the existence of certain total recursive functions in nontrivial axiom systems , I',
#  'Doria, F. A.': 'On the existence of certain total recursive functions in nontrivial axiom systems , I',
#  'Pagel, V.': 'Spotting Prosodic Boundaries in Continuous Speech in French',
#  'Lenzo, K.': 'Letter to Sound Rules for Accented Lexicon Compression',
#  'Black, A.': 'Letter to Sound Rules for Accented Lexicon Compression',
#  'Carbonell, N.': 'Spotting Prosodic Boundaries in Continuous Speech in French',
#  'Vaissiere, J.': 'Spotting Prosodic Boundaries in Continuous Speech in French',
#  'LI, Hang': 'A Probabilistic Approach to Lexical Semantic Knowledge Acquisition and S tructural Disambiguation',
#  'Chechik, M.': 'Events in Property Patterns',
#  'Paun, D.': 'Events in Property Patterns',
#  'Berri, J.': 'A Real World Implementation of Answer Extraction',
#  'Litkowski, K.': 'Requirements of Text Processing Lexicons',
#  'Ries, K.': 'Can Prosody Aid the Automatic Classification of Dialog Acts in Conversational Speech ?',
#  'Coccaro, N.': 'Can Prosody Aid the Automatic Classification of Dialog Acts in Conversational Speech ?',
#  'Shriberg, E.': 'Integrating Prosodic and Lexical Cues for Automatic Topic Segmentation',
#  'Bates, R.': 'Can Prosody Aid the Automatic Classification of Dialog Acts in Conversational Speech ?',
#  'Taylor, P.': 'Can Prosody Aid the Automatic Classification of Dialog Acts in Conversational Speech ?',
#  'Meteer, M.': 'Can Prosody Aid the Automatic Classification of Dialog Acts in Conversational Speech ?',
#  'Tan, Wang-Chiew': 'Towards a query language for annotation graphs',
#  'Martins, J. F.': 'Language identification of controlled systems : Modelling , control and anomaly detection',
#  'Dente, J. A.': 'Language identification of controlled systems : Modelling , control and anomaly detection',
#  'Pires, A. J.': 'Language identification of controlled systems : Modelling , control and anomaly detection',
#  'Mendes, R. Vilela': 'Language identification of controlled systems : Modelling , control and anomaly detection',
#  'Mangu, L.': 'Finding consensus in speech recognition : word error minimization and other applications of confusion networks',
#  'Daudé, J.': 'A Complete WordNet1.5 to WordNet1.6 Mapping',
#  'Padró, L.': 'A Complete WordNet1.5 to WordNet1.6 Mapping',
#  'Shan, Chung-chieh': 'Polarity sensitivity and evaluation order in type-logical grammar',
#  'Castano, J.': 'Rerendering Semantic Ontologies : Automatic Extensions to UMLS through Corpus Analytics',
#  'Lecomte, P.': 'Real numbers having ultimately periodic representations in abstract numeration systems',
#  'Rigo, M.': 'Real numbers having ultimately periodic representations in abstract numeration systems',
#  'Sriram, V.': 'Approximate Grammar for Information Extraction',
#  'Bendre, S. M.': 'An Algorithm for Aligning Sentences in Bilingual Corpora Using Lexical Information',
#  'Maslov, V. P.': 'About compression of vocabulary in computer oriented languages',
#  'Wolff, J Gerard': 'Syntax , Parsing and Production of Natural Language in a Framework of Information Compression by Multiple Alignment , Unification and Search',
#  'Jia, Jiyou': 'The Generation of Textual Entailment with NLML in an Intelligent Dialogue system for Language Learning CSIEC',
#  'Usatenko, O. V.': 'Symbolic stochastic dynamical systems viewed as binary N-step Markov chains',
#  "Yampol'skii, V. A.": 'Symbolic stochastic dynamical systems viewed as binary N-step Markov chains',
#  'Kechedzhy, K. E.': 'Symbolic stochastic dynamical systems viewed as binary N-step Markov chains',
#  "Mel'nyk, S. S.": 'Symbolic stochastic dynamical systems viewed as binary N-step Markov chains',
#  'Miram, G. E.': 'A Probabilistic Model of Machine Translation',
#  'Petrov, V. K.': 'A Probabilistic Model of Machine Translation',
#  'Paijmans, J. J.': 'Building a linguistic corpus from bee dance data',
#  'Tsalidis, Ch.': 'An electronic dictionary as a basis for NLP tools : The Greek case',
#  'Orphanos, G.': 'An electronic dictionary as a basis for NLP tools : The Greek case',
#  'Iordanidou, A.': 'Proofing Tools Technology at Neurosoft S.A .',
#  'Ke, J-Y': 'Analyzing language development from a network approach',
#  'Hou, Shufen': 'Improving the CSIEC Project and Adapting It to the English Teaching and Learning in China',
#  'Chen, Weichao': 'Improving the CSIEC Project and Adapting It to the English Teaching and Learning in China',
#  'Laros, J. F. J.': 'Numeration-automatic sequences',
#  'Satori, H.': 'Arabic Speech Recognition System using CMU-Sphinx4',
#  'Harti, M.': 'Arabic Speech Recognition System using CMU-Sphinx4',
#  'Hsu, Wen-Lien': 'On the Development of Text Input Method - Lessons Learned',
#  'Hsieh, Meng-Juei': 'On the Development of Text Input Method - Lessons Learned',
#  'Krizhanovsky, A. A.': 'Index wiki database : design and experiments',
#  'Lande, D. V.': 'Compactified Horizontal Visibility Graph for the Language Network',
#  'Snarskii, A. A.': 'Compactified Horizontal Visibility Graph for the Language Network',
#  'Braichevsky, S.': 'On the fractal nature of mutual relevance sequences in the Internet news message flows',
#  'Snarskii, A.': 'On the fractal nature of mutual relevance sequences in the Internet news message flows',
#  'Tamara, Tretjakova': 'Nontraditional Scoring of C-tests',
#  'Halatsis, C.': 'Using Synchronic and Diachronic Relations for Summarizing Multiple Documents Describing Evolving Events',
#  'Suslov, I. M.': "How to realize `` a sense of humour '' in computers ?",
#  'Huh, Hyun-Gue': 'A resource-based Korean morphological annotation system',
#  'Wichmann, S.': 'Malagasy Dialects and the Peopling of Madagascar',
#  'Gillet, J.': 'A Comparison of natural ( english ) and artificial ( esperanto ) languages . A Multifractal method based analysis',
#  'Ausloos, M.': 'Punctuation effects in English and Esperanto texts',
#  'Rothenberger, T.': 'Figuring out Actors in Text Streams : Using Collocations to establish Incremental Mind-maps',
#  'Oez, S.': 'Figuring out Actors in Text Streams : Using Collocations to establish Incremental Mind-maps',
#  'Tahirovic, E.': 'Figuring out Actors in Text Streams : Using Collocations to establish Incremental Mind-maps',
#  'Smirnov, A. V.': 'Information filtering based on wiki index database',
#  'Masse, A. Blondin': 'How Is Meaning Grounded in Dictionary Definitions ?',
#  'Zhygalo, V. V.': 'About the creation of a parallel bilingual corpora of web-publications',
#  'Korutcheva, E.': 'Text as Statistical Mechanics Object',
#  'Dhami, H. S.': 'Suffix Stripping Problem as an Optimization Problem',
#  'Leow, Wee-Kheng': 'Prospective Study for Semantic Inter-Media Fusion in Content-Based Medical Image Retrieval',
#  'Borge, J.': 'A Computational Model to Disentangle Semantic Information Embedded in Word Association Norms',
#  'Arenas, A.': 'A Computational Model to Disentangle Semantic Information Embedded in Word Association Norms',
#  'Vahia, M. N.': 'Statistical analysis of the Indus script using $ n $ -grams',
#  'Nelson, D.': 'Extracting Spooky-activation-at-a-distance from Considerations of Entanglement',
#  'McEvoy, C.': 'Extracting Spooky-activation-at-a-distance from Considerations of Entanglement',
#  'Kossinets, Gueorgi': 'How opinions are received by online communities : A case study on Amazon.com helpfulness votes',
#  'Gilkey, P.': 'Mathematics , Recursion , and Universals in Human Languages',
#  'Karousou, A.': 'Mathematics , Recursion , and Universals in Human Languages',
#  'Rama, N.': 'A New Computational Schema for Euphonic Conjunctions in Sanskrit Processing',
#  'Khan, M. A.': 'A Discourse-based Approach in Text-based Machine Translation',
#  'Hussain, M. Asdaque': 'Resolution of Unidentified Words in Machine Translation',
#  'Kalyani, N.': 'Syllable Analysis to Build a Dictation System in Telugu language',
#  'Sunitha, Dr K. V. N.': 'Syllable Analysis to Build a Dictation System in Telugu language',
#  'Anusuya, M. A.': 'Speech Recognition by Machine , A Review',
#  'Katti, S. K.': 'Speech Recognition by Machine , A Review',
#  'Suleesathira, Raungrong': 'Co-channel Interference Cancellation for Space-Time Coded OFDM Systems Using Adaptive Beamforming and Null Deepening',
#  'Chen, Chien-Ying': 'Plagiarism Detection using ROUGE and WordNet',
#  'Yeh, Jen-Yuan': 'Plagiarism Detection using ROUGE and WordNet',
#  'Ke, Hao-Ren': 'Plagiarism Detection using ROUGE and WordNet',
#  'Samer, Taalab': "Etiqueter un corpus oral par apprentissage automatique \\`a l'aide de connaissances linguistiques",
#  'Zaidan, A. A': 'Offline Arabic Handwriting Recognition Using Artificial Neural Network',
#  'Zaidan, B. B': 'Offline Arabic Handwriting Recognition Using Artificial Neural Network',
#  'Jalab, Hamid. A.': 'Offline Arabic Handwriting Recognition Using Artificial Neural Network',
#  'Alanazi, Hamdan. O.': 'Offline Arabic Handwriting Recognition Using Artificial Neural Network',
#  'Stevanak, J. T.': 'Distinguishing Fact from Fiction : Pattern Recognition in Texts Using Complex Networks',
#  'Wen, Yicheng': 'Pattern Classification In Symbolic Streams via Semantic Annihilation of Information',
#  'Chen, Ke': 'Learning Contextualized Semantics from Co-occurring Terms via a Siamese Architecture',
#  'Marian, Zsuzsana': 'Learning Taxonomy for Text Segmentation by Formal Concept Analysis',
#  'Mao, Huina': 'Happiness is assortative in online social networks',
#  'Volchenkov, D.': 'Malagasy Dialects and the Peopling of Madagascar',
#  'Ruan, Guangchen': 'The happiness paradox : your friends are happier than you',
#  'Li, Wentian': 'Characterizing Ranked Chinese Syllable-to-Character Mapping Spectrum : A Bridge Between the Spoken and Written Chinese Language',
#  'Rao, R. Rajeswara': 'Performance Evaluation of Statistical Approaches for Text Independent Speaker Recognition Using Source Feature',
#  'Nagesh, A.': 'Performance Evaluation of Statistical Approaches for Text Independent Speaker Recognition Using Source Feature',
#  'Barisevičius, G.': 'Multilingual lexicon design tool and database management system for MT',
#  'Tamulynas, B.': 'Multilingual lexicon design tool and database management system for MT',
#  'Pramod, K. V.': 'Handwritten Character Recognition of South Indian Scripts : A Review',
#  'van Rijsbergen, C. J.': 'Quantum-Like Uncertain Conditionals for Text Analysis',
#  'Martinez-Barco, P.': 'Computational Approach to Anaphora Resolution in Spanish Dialogues',
#  'Ferrandez, A.': 'Translation of Pronominal Anaphora between English and Spanish : Discrepancies and Evaluation',
#  'Peral, J.': 'Translation of Pronominal Anaphora between English and Spanish : Discrepancies and Evaluation',
#  'Robertson, R.': 'Acquiring Correct Knowledge for Natural Language Generation',
#  'Sripada, S. G.': 'Acquiring Correct Knowledge for Natural Language Generation',
#  'Michel, Musiol': "Une analyse bas\\'ee sur la S-DRT pour la mod\\'elisation de dialogues pathologiques",
#  'Manuel, Rebuschi': "Une analyse bas\\'ee sur la S-DRT pour la mod\\'elisation de dialogues pathologiques",
#  'Lahiri, Shibamouli': 'A New Bengali Readability Score',
#  'Montoyo, A.': 'Combining Knowledge- and Corpus-based Word-Sense-Disambiguation Methods',
#  'Suarez, A.': 'Combining Knowledge- and Corpus-based Word-Sense-Disambiguation Methods',
#  'Choi, K.': 'A Comparison of Different Machine Transliteration Models',
#  'Shivaswamy, Pannaga': 'Large-Margin Learning of Submodular Summarization Methods',
#  'Evans, R. J.': 'NP Animacy Identification for Anaphora Resolution',
#  'Orasan, C.': 'NP Animacy Identification for Anaphora Resolution',
#  'Xiang, Luojie': 'Ideogram Based Chinese Sentiment Word Orientation Computation',
#  'Mairesse, F.': 'Individual and Domain Adaptation in Sentence Planning for Dialogue',
#  'Prasad, R.': 'Individual and Domain Adaptation in Sentence Planning for Dialogue',
#  'Nongmeikapam, Kishorjit': 'Automatic Segmentation of Manipuri ( Meiteilon ) Word into Syllabic Units',
#  'Stavroula, Voyatzi': 'Extending the adverbial coverage of a NLP oriented resource for French',
#  'Riad, A. M.': 'SignsWorld ; Deeping Into the Silence World and Hearing Its Signs ( State of the Art )',
#  'Shohieb, Samaa. M.': 'SignsWorld ; Deeping Into the Silence World and Hearing Its Signs ( State of the Art )',
#  'Asem, A. S.': 'SignsWorld ; Deeping Into the Silence World and Hearing Its Signs ( State of the Art )',
#  'Nonglenjaoba, Lairenlakpam': 'Reduplicated MWE ( RMWE ) helps in improving the CRF based Manipuri POS Tagger',
#  'Burman, Amev': 'USFD at KBP 2011 : Entity Linking , Slot Filling and Temporal Bounding',
#  'Shams, Rushdi': 'Semi-supervised Classification for Natural Language Processing',
#  'Divakaran, Sajilal': 'Spectral Analysis of Projection Histogram for Enhancing Close matching character Recognition in Malayalam',
#  'Song, Peiyou': 'Language Without Words : A Pointillist Model for Natural Language Processing',
#  'Wiriyathammabhum, Peratham': 'Applying Deep Belief Networks to Word Sense Disambiguation',
#  'Kim, Hyonil': 'A Method for Selecting Noun Sense using Co-occurrence Relation in English-Korean Translation',
#  'Choe, Changil': 'A Method for Selecting Noun Sense using Co-occurrence Relation in English-Korean Translation',
#  'Huang, Liusheng': 'More than Word Frequencies : Authorship Attribution via Natural Frequency Zoned Word Distribution Analysis',
#  'Hicham, Gueddah': 'Introduction of the weight edition errors in the Levenshtein distance',
#  'El-Dosuky, M. A.': 'Robopinion : Opinion Mining Framework Inspired by Autonomous Robot Navigation',
#  'Rashad, M. Z.': 'Robopinion : Opinion Mining Framework Inspired by Autonomous Robot Navigation',
#  'Hamza, T. T.': 'Robopinion : Opinion Mining Framework Inspired by Autonomous Robot Navigation',
#  'EL-Bassiouny, A. H.': 'Robopinion : Opinion Mining Framework Inspired by Autonomous Robot Navigation',
#  'Balamurali, A. R.': 'TwiSent : A Multistage System for Analyzing Sentiment in Twitter',
#  'Tsai, Hsiang-Ping': 'Opinion Mining for Relating Subjective Expressions and Annual Earnings in US Financial Statements',
#  'Tsai, Chia-Chi': 'Hidden Trends in 90 Years of Harvard Business Review',
#  'Huang, Wei-Jie': 'Exploring Lexical , Syntactic , and Semantic Features for Chinese Textual Entailment in NTCIR RITE Evaluation Tasks',
#  'Jin, Guantao': 'Some Chances and Challenges in Applying Language Technologies to Historical Studies in Chinese',
#  'Yu, Yih-Soong': 'Some Chances and Challenges in Applying Language Technologies to Historical Studies in Chinese',
#  'Prasad, S. V. A. V.': 'A Hindi Speech Actuated Computer Interface for Web Search',
#  'Prasad, T. V.': 'A Hindi Speech Actuated Computer Interface for Web Search',
#  'Ahn, Ae-Lim': 'Semantic Polarity of Adjectival Predicates in Online Reviews',
#  'Wu, Ke': 'Minimally Supervised Written-to-Spoken Text Normalization',
#  'Yang, Shuang-Hong': 'A Scale-Space Theory for Text',
#  'Kang, Jeon-Hyung': 'Transfer Topic Modeling with Ease and Scalability',
#  'Zhang, Yao-Zhong': 'Multi-Step Regression Learning for Compositional Distributional Semantics',
#  'Lachkar, Abdelmonaime': 'A new keyphrases extraction method based on suffix tree data structure for arabic documents clustering',
#  'Deng, Weibing': 'Stochastic model for phonemes uncovers an author-dependency of their usage',
#  'Wang, Q. A.': 'Rank-frequency relation for Chinese characters',
#  'Liu, Sa': 'Termhood-based Comparability Metrics of Comparable Corpus in Special Domain',
#  'R, Kanagavalli V': 'Detecting and resolving spatial ambiguity in text using named entity extraction and self learning fuzzy logic techniques',
#  'K, Raja.': 'Detecting and resolving spatial ambiguity in text using named entity extraction and self learning fuzzy logic techniques',
#  'Di, Zengru': 'Efficient learning strategy of Chinese characters based on network approach',
#  'Thakare, VM': 'Adverse Conditions and ASR Techniques for Robust Speech User Interface',
#  'Lusseau, D.': 'Parallels of human language in the behavior of bottlenose dolphins',
#  'Hashem, M. M. A.': 'Corpus-based Web Document Summarization using Statistical and Linguistic Approach',
#  'Abchir, M. -A.': 'Dealing with natural language interfaces in a geolocation context',
#  'Prasad, Dr. T. V.': 'CONATION : English Command Input/Output System for Computers',
#  'Kwon, Keehang': 'Accomplishable Tasks in Knowledge Representation',
#  'Arora, Suket': 'Punjabi Language Interface to Database : a brief review',
#  'Chandak, Dr. M. B.': 'Opinion Mining and Analysis : A survey',
#  'Sandanalakshmi, R.': 'Speaker Independent Continuous Speech to Text Converter for Mobile Application',
#  'Viji, P. Abinaya': 'Speaker Independent Continuous Speech to Text Converter for Mobile Application',
#  'Kiruthiga, M.': 'Speaker Independent Continuous Speech to Text Converter for Mobile Application',
#  'Manjari, M.': 'Speaker Independent Continuous Speech to Text Converter for Mobile Application',
#  'Sharina, M.': 'Speaker Independent Continuous Speech to Text Converter for Mobile Application',
#  'Sharma, A. K.': 'A Novel Architecture For Question Classification Based Indexing Scheme For Efficient Question Answering',
#  'Sharma, A. K': 'A Novel Architecture for Relevant Blog Page Identifcation',
#  'Paxton, A.': 'B ( eo ) W ( u ) LF : Facilitating recurrence analysis on multi-level language',
#  'Karray, H.': 'Arabic Text Recognition in Video Sequences',
#  'Alimi, A. M.': 'Arabic Text Recognition in Video Sequences',
#  'Rahman, Md. Mijanur': 'Implementation Of Back-Propagation Neural Network For Isolated Bangla Speech Recognition',
#  'Khan, Md. Farukuzzaman': 'Implementation Of Back-Propagation Neural Network For Isolated Bangla Speech Recognition',
#  'Siddharth, N.': "Saying What You 're Looking For : Linguistics Meets Video Search",
#  'Luo, Juan': 'An Investigation of the Sampling-Based Alignment Method and Its Contributions',
#  'Virdee, Kawandeep': 'Sentiment in New York City : A High Resolution Spatial and Temporal View',
#  'Bar-Yam, Yaneer': 'Sentiment in New York City : A High Resolution Spatial and Temporal View',
#  'Thangarasu, M.': 'Stemmers for Tamil Language : Performance Analysis',
#  'Manavalan, R.': 'Stemmers for Tamil Language : Performance Analysis',
#  'Zhu, Song-Chun': 'Joint Image-Text News Topic Detection and Tracking with And-Or Graph Representation',
#  'Deng, W. B.': 'Quantitative Entropy Study of Language Complexity',
#  'Li, B.': 'Rank-frequency relation for Chinese characters',
#  'Arbib, M. A.': 'Recognizing Speech in a Novel Accent : The Motor Theory of Speech Perception Reframed',
#  'LanJun, Zhou': 'Domain-Specific Sentiment Word Extraction by Seed Expansion and Pattern Generation',
#  'Yanyan, Zhao': 'Domain-Specific Sentiment Word Extraction by Seed Expansion and Pattern Generation',
#  'Xie, Pengtao': 'Convolutional Neural Networks for Medical Diagnosis from Admission Notes',
#  'Chen, Hsinchun': 'Evaluating the Usefulness of Sentiment Information for Focused Crawlers',
#  'Malakar, Mancha Jyoti': 'Development and Transcription of Assamese Speech Corpus',
#  'Elayidom, M. Sudheep': 'Text Classification For Authorship Attribution Analysis',
#  'Jose, Chinchu': 'Text Classification For Authorship Attribution Analysis',
#  'Kiamarzpour, Foruzan': 'Improving the methods of email classification based on words ontology',
#  'Liu, Zitao': 'A Comparative Study on Linguistic Feature Selection in Sentiment Polarity Classification',
#  'Raj, P. C. Reghu': 'Architecture of an Ontology-Based Domain-Specific Natural Language Question Answering System',
#  'Beheshti, Seyed-Mehdi-Reza': 'Data Curation APIs',
#  'Cai, Tianxi': 'A Short Introduction to NILE',
#  'Yih, Wen-tau': 'Cross-Sentence N-ary Relation Extraction with Graph LSTMs',
#  'Deng, Li': 'BBQ-Networks : Efficient Exploration in Deep Reinforcement Learning for Task-Oriented Dialogue Systems',
#  'Li, Rumeng': 'Time-dependent Hierarchical Dirichlet Model for Timeline Generation',
#  'Ge, Qi': 'One Billion Word Benchmark for Measuring Progress in Statistical Language Modeling',
#  'Pande, B. P.': 'Suffix Stripping Problem as an Optimization Problem',
#  'Paramesha, K': 'A Perspective on Sentiment Analysis',
#  'Singh, Mittul': 'Long-Short Range Context Neural Networks for Language Modeling',
#  'Chowdhury, Md. Naseef-Ur-Rahman': 'Statistical Analysis based Hypothesis Testing Method in Biological Knowledge Discovery',
#  'Paul, Suvankar': 'Statistical Analysis based Hypothesis Testing Method in Biological Knowledge Discovery',
#  'Kapetanios, E.': 'Hrebs and Cohesion Chains as similar tools for semantic text properties research',
#  'Dong, Li': 'Learning to Paraphrase for Question Answering',
#  'Karattil, Sajeer': 'Software Requirement Specification Using Reverse Speech Technology',
#  'Rajan, K.': 'Machine Learning of Phonologically Conditioned Noun Declensions For Tamil Morphological Generators',
#  'Ramalingam, Dr. V.': 'Machine Learning of Phonologically Conditioned Noun Declensions For Tamil Morphological Generators',
#  'Ganesan, Dr. M.': 'Machine Learning of Phonologically Conditioned Noun Declensions For Tamil Morphological Generators',
#  'Zhu, Linhong': 'Tripartite Graph Clustering for Dynamic Sentiment Analysis on Social Media',
#  'Lall, Brejesh': 'Improving Collaborative Filtering based Recommenders using Topic Modelling',
#  'Jiffriya, M. A. C.': 'AntiPlag : Plagiarism Detection on Electronic Submissions of Text Based Assignments',
#  'Deegalla, S.': 'AntiPlag : Plagiarism Detection on Electronic Submissions of Text Based Assignments',
#  'Herath, P.': 'Authorship detection of SMS messages using unigrams',
#  'Senanayake, U.': 'Authorship detection of SMS messages using unigrams',
#  'Haque, Md. Ansarul': 'Sentiment Analysis by Using Fuzzy Logic',
#  'Song, Yanglei': 'Scalable Topical Phrase Mining from Text Corpora',
#  'Sureka, K.': 'An efficiency dependency parser using hybrid approach for tamil language',
#  'Srinivasagan, K. G.': 'An efficiency dependency parser using hybrid approach for tamil language',
#  'Suganthi, S.': 'An efficiency dependency parser using hybrid approach for tamil language',
#  'Shi, Qiuhui': 'Emotion Analysis Platform on Chinese Microblog',
#  'Zhang, Jinglan': 'Aspect-Based Opinion Extraction from Customer reviews',
#  'Bijal, Dalwadi': 'Overview of Stemming Algorithms for Indian and Non-Indian Languages',
#  'Sanket, Suthar': 'Overview of Stemming Algorithms for Indian and Non-Indian Languages',
#  'Tupper, P. F.': 'Effects of Limiting Memory Capacity on the Behaviour of Exemplar Dynamics',
#  'Hanane, Tebbi': 'An Expert System for Automatic Reading of A Text Written in Standard Arabic',
#  'Hamid, Azzoune': 'An Expert System for Automatic Reading of A Text Written in Standard Arabic',
#  'Popescul, Alexandrin': 'Learning Alternative Name Spellings',
#  'Hakro, Dil Nawaz': 'Phonetic based SoundEx & ShapeEx algorithm for Sindhi Spell Checker System',
#  'Chiu, Yi-I': 'Temporal Analysis of Language through Neural Language Models',
#  'Wu, Dalei': 'Modelling Data Dispersion Degree in Automatic Robust Estimation for Multivariate Gaussian Mixture Models with an Application to Noisy Speech Processing',
#  'Almishari, Mishari': 'Fighting Authorship Linkability with Crowdsourcing',
#  'Cha, Meeyoung': 'Comparing and Combining Sentiment Analysis Methods',
#  'El-Sammak, A.': 'The Best Templates Match Technique For Example Based Machine Translation',
#  'Laxminarayana, M': 'Basis Identification for Automatic Creation of Pronunciation Lexicon for Proper Names',
#  'Liu, Peilei': 'Neural Mechanism of Language',
#  'Ghanbarnejad, Fakhteh': 'Extracting information from S-curves of language change',
#  'Fei-Fei, Li': 'Inferring and Executing Programs for Visual Reasoning',
#  'Liu, Tie-Yan': 'Adversarial Neural Machine Translation',
#  'Qiu, Siyu': 'A Continuously Growing Dataset of Sentential Paraphrases',
#  'Jayaweera, A. J. P. M. P.': 'Unknown Words Analysis in POS tagging of Sinhala Language',
#  'Dias, N. G. J.': 'Unknown Words Analysis in POS tagging of Sinhala Language',
#  'Liu, Bo': "Understanding Zipf 's law of word frequencies through sample-space collapse in sentence formation",
#  'Macdonell, S. G.': 'Autonomous requirements specification processing using natural language processing',
#  'Min, K.': 'Autonomous requirements specification processing using natural language processing',
#  'Connor, A. M.': 'Autonomous requirements specification processing using natural language processing',
#  'Shan, Zifei': 'Feature Engineering for Knowledge Base Construction',
#  'Shin, Jaeho': 'Incremental Knowledge Base Construction Using DeepDive',
#  'Wang, Feiran': 'Incremental Knowledge Base Construction Using DeepDive',
#  'Ji, Zongcheng': 'An Information Retrieval Approach to Short Text Conversation',
#  'Lu, Zhengdong': 'Event Identification as a Decision Process with Non-linear Representation of Text',
#  'Traag, V. A.': 'Structure of a media co-occurrence network',
#  'Reinanda, R.': 'Structure of a media co-occurrence network',
#  'van Klinken, G.': 'Structure of a media co-occurrence network',
#  'Nizamee, Renesa': 'Approximating solution structure of the Weighted Sentence Alignment problem',
#  'Wang, Naiyan': 'Collaborative Deep Learning for Recommender Systems',
#  'Yeung, Dit-Yan': 'Collaborative Recurrent Autoencoder : Recommend while Learning to Fill in the Blanks',
#  'Mei, Qiaozhu': 'Find the Conversation Killers : a Predictive Study of Thread-ending Posts',
#  'Rajitha, V.': 'An Ontology for Comprehensive Tutoring of Euphonic Conjunctions of Sanskrit Grammar',
#  'Dhanalakshmi, V.': 'Improving the Performance of English-Tamil Statistical Machine Translation System using Source-Side Pre-Processing',
#  'Sharmiladevi, V.': 'Improving the Performance of English-Tamil Statistical Machine Translation System using Source-Side Pre-Processing',
#  'Cho, KyungHyun': 'Not All Neural Embeddings are Born Equal',
#  'Amine, Chennoufi': 'Hybrid approaches for automatic vowelization of Arabic texts',
#  'Azzeddine, Mazroui': 'Hybrid approaches for automatic vowelization of Arabic texts',
#  'Abdelhak, Lakhouaja': 'Hybrid approaches for automatic vowelization of Arabic texts',
#  'Zhu, Peiyan': 'Sentiment Analysis based on User Tag for Traditional Chinese Medicine in Weibo',
#  'Li, Xiangang': 'Deep Speaker : an End-to-End Neural Speaker Embedding System',
#  'Huang, Xiaolei': 'Using Linguistic Features to Estimate Suicide Probability of Chinese Microblog Users',
#  'Zhu, Tingshao': 'Recognizing Temporal Linguistic Expression Pattern of Individual with Suicide Risk on Social Media',
#  'Chen, Zhenxiang': 'Using Linguistic Features to Estimate Suicide Probability of Chinese Microblog Users',
#  'Guo, Fangjian': 'The Bayesian Echo Chamber : Modeling Social Influence via Linguistic Accommodation',
#  'Song, Li Kum': 'Definition of Visual Speech Element and Research on a Method of Extracting Feature Vector for Korean Lip-Reading',
#  'Cheng, Jianpeng': 'Learning an Executable Neural Semantic Parser',
#  'Ramos-Soto, A.': 'Fuzzy Sets Across the Natural Language Generation Pipeline',
#  'Bugarín, A.': 'Fuzzy Sets Across the Natural Language Generation Pipeline',
#  'Barro, S.': 'Fuzzy Sets Across the Natural Language Generation Pipeline',
#  'Taboada, J.': 'Linguistic Descriptions for Automatic Generation of Textual Short-Term Weather Forecasts on Real Prediction Data',
#  'Shi, Tianze': 'Fast ( er ) Exact Decoding and Global Training for Transition-Based Dependency Parsing via a Minimal Feature Set',
#  'Gao, Shuyang': 'Efficient Representation for Natural Language Processing via Kernelized Hashcodes',
#  'Wang, Xiuli': "Zipf 's Law and the Frequency of Characters or Words of Oracles",
#  'Xu, Huijuan': 'Ask , Attend and Answer : Exploring Question-Guided Spatial Attention for Visual Question Answering',
#  'Lin, Ruokuang': 'Scaling laws in human speech , decreasing emergence of new words and a generalized model',
#  'Zhao, Jichang': 'Word Network Topic Model : A Simple but General Solution for Short and Imbalanced Texts',
#  'Rajitha, V': 'Computational Model to Generate Case-Inflected Forms of Masculine Nouns for Word Search in Sanskrit E-Text',
#  'Nam, Jinseok': 'On Learning Vector Representations in Hierarchical Label Spaces',
#  'Miao, Yishu': 'Discovering Discrete Latent Topics with Neural Variational Inference',
#  'Moussa, Assema': 'Optimisation using Natural Language Processing : Personalized Tour Recommendation for Museums',
#  'Chen, Geliang': 'Phrase Based Language Model for Statistical Machine Translation : Empirical Study',
#  'Rachad, T.': 'A New Efficient Method for Calculating Similarity Between Web Services',
#  'Boutahar, J.': 'A New Efficient Method for Calculating Similarity Between Web Services',
#  'ghazi, S. El': 'A New Efficient Method for Calculating Similarity Between Web Services',
#  'Da Silva, E. L. F.': 'Implementation of an Automatic Syllabic Division Algorithm from Speech Files in Portuguese Language',
#  'de Oliveira, H. M.': 'Implementation of an Automatic Syllabic Division Algorithm from Speech Files in Portuguese Language',
#  'Prasad, Niranjani': 'Scaling Recurrent Neural Network Language Models',
#  'Zhang, Yongfeng': 'Boost Phrase-level Polarity Labelling with Review-level Sentiment Classification',
#  'Liang, Yingyu': 'Mapping Between fMRI Responses to Movies and their Natural Language Annotations',
#  'Ma, Tengyu': 'Linear Algebraic Structure of Word Senses , with Applications to Polysemy',
#  'Cui, Tianyi': 'Ordering-sensitive and Semantic-aware Topic Modeling',
#  'Shen, Yelong': 'Stochastic Answer Networks for Machine Reading Comprehension',
#  'Yao, Li': 'Oracle performance for visual captioning',
#  'Huang, Shujian': 'Modeling Past and Future for Neural Machine Translation',
#  'Hovy, Eudard': 'When Are Tree Structures Necessary for Deep Learning of Representations ?',
#  'Wu, Jiadong': 'Maximum a Posteriori Adaptation of Network Parameters in Deep Models',
#  'Hu, Baotian': 'Answer Sequence Learning with Neural Networks for Answer Selection in Community Question Answering',
#  'Chen, Qingcai': 'Answer Sequence Learning with Neural Networks for Answer Selection in Community Question Answering',
#  'Lin, Huei-Chi': 'On Using Monolingual Corpora in Neural Machine Translation',
#  'Sobhani, Parinaz': 'Stance and Sentiment in Tweets',
#  'He, He': 'Learning Symmetric Collaborative Dialogue Agents with Dynamic Knowledge Graph Embeddings',
#  'Pak, Myong-Chol': 'Phrase database Approach to structural and semantic disambiguation in English-Korean Machine Translation',
#  'Kwak, Haewoon': 'Breaking the News : First Impressions Matter on Online News',
#  'Zhang, Guangquan': 'Nonparametric Relational Topic Models through Dependent Gamma Processes',
#  'Sukhbaatar, Sainbayar': 'Simple Baseline for Visual Question Answering',
#  'Lin, Tsung-Yi': 'Microsoft COCO Captions : Data Collection and Evaluation Server',
#  'Li, Ge': 'Why Do Neural Dialog Systems Generate Short and Meaningless Replies ? A Comparison between Dialog and Translation',
#  'Wang, Hongsu': "Character Distributions of Classical Chinese Literary Texts : Zipf 's Law , Genres , and Epochs",
#  'Seguin, C.': "Compression and the origins of Zipf 's law of abbreviation",
#  'Hou, Weiwei': 'Named Entity Recognition for Novel Types by Transfer Learning',
#  'Li, Piji': 'Reader-Aware Multi-Document Summarization : An Enhanced Model and The First Dataset',
#  'Bing, Lidong': 'Reader-Aware Multi-Document Summarization : An Enhanced Model and The First Dataset',
#  'Liao, Yi': 'Abstractive Multi-Document Summarization via Phrase Selection and Merging',
#  'Rizoiu, Marian-Andrei': 'CommentWatcher : An Open Source Web-based platform for analyzing discussions on web forums',
#  'Song, Shuangyong': 'Modelling Domain Relationships for Transfer Learning on Retrieval-based Question Answering Systems in E-commerce',
#  'Lu, Jiasen': 'Best of Both Worlds : Transferring Knowledge from Discriminative Learning to a Generative Visual Dialog Model',
#  'Zheng, Zhongguang': 'A Feature-based Classification Technique for Answering Multi-choice World History Questions',
#  'Xu, Mingbin': 'A FOFE-based Local Detection Approach for Named Entity Recognition and Mention Detection',
#  'Ren, Mengye': 'Exploring Models and Data for Image Question Answering',
#  'Yu, Mo': 'Evidence Aggregation for Answer Re-Ranking in Open-Domain Question Answering',
#  'Achary, K. K.': "Feature selection using Fisher 's ratio technique for automatic speech recognition",
#  'Chen, Enhong': 'Chinese Poetry Generation with Planning based Neural Network',
#  'Zhou, Mantong': 'An Interpretable Reasoning Network for Multi-Relation Question Answering',
#  'Hao, Yu': 'TransA : An Adaptive Approach for Knowledge Graph Embedding',
#  'Gao, Haoyuan': 'Are You Talking to a Machine ? Dataset and Methods for Multilingual Image Question Answering',
#  'Chen, Xinchi': 'DAG-based Long Short-Term Memory for Neural Word Segmentation',
#  'Huang, Xuanjing': 'DAG-based Long Short-Term Memory for Neural Word Segmentation',
#  'Kuo, Hong-Kwang J.': 'The IBM 2016 English Conversational Telephone Speech Recognition System',
#  'Li, Lantian': 'Human and Machine Speaker Recognition Based on Short Trivial Events',
#  'Beltagy, I.': 'Representing Meaning with a Combination of Logical and Distributional Models',
#  'Cheng, Pengxiang': 'Representing Meaning with a Combination of Logical and Distributional Models',
#  'Yin, Liusong': 'Overview of the NLPCC 2015 Shared Task : Chinese Word Segmentation and POS Tagging for Micro-blog Texts',
#  'Wang, Huazheng': 'Solving Verbal Comprehension Questions in IQ Test by Knowledge-Powered Word Embedding',
#  'Mao, Kezhi': 'Supervised Fine Tuning for Word Embedding with Integrated Knowledge',
#  'Park, Gilchan': 'Using Syntactic Features for Phishing Detection',
#  'Yao, Kaisheng': 'An Attentional Neural Conversation Model with Improved Specificity',
#  'Park, Eunbyung': 'Visual Madlibs : Fill in the blank Image Generation and Question Answering',
#  'Luan, Huanbo': 'THUMT : An Open Source Toolkit for Neural Machine Translation',
#  'Bastan, Mohadeseh': 'Monolingually Derived Phrase Scores for Phrase Based SMT Using Neural Networks Vector Representations',
#  'Liao, Han-Teng': 'How much is said in a microblog ? A multilingual inquiry based on Weibo and Twitter',
#  'Fu, King-wa': 'How much is said in a microblog ? A multilingual inquiry based on Weibo and Twitter',
#  'Cao, Donglin': 'Video ( GIF ) Sentiment Analysis using Large-Scale Mid-Level Ontology',
#  'Tseng, Bo-Hsiang': 'Towards Machine Comprehension of Spoken Content : Initial TOEFL Listening Comprehension Test by Machine',
#  'Shivakrishna, D.': 'Hybridized Feature Extraction and Acoustic Modelling Approach for Dysarthric Speech Recognition',
#  'Lu, Hsiang-Hung': 'An Iterative Deep Learning Framework for Unsupervised Discovery of Speech Features and Linguistic Units with Applications on Spoken Term Detection',
#  'Liou, Yuan-ming': 'A Multi-layered Acoustic Tokenizing Deep Neural Network ( MAT-DNN ) for Unsupervised Discovery of Linguistic Units and Generation of High Quality Features',
#  'Lu, Yen-Ju': 'A Multi-layered Acoustic Tokenizing Deep Neural Network ( MAT-DNN ) for Unsupervised Discovery of Linguistic Units and Generation of High Quality Features',
#  'Yun, Hyokun': 'Deep Active Learning for Named Entity Recognition',
#  'Vishwanathan, S. V. N.': 'BlackOut : Speeding up Recurrent Neural Network Language Models With Very Large Vocabularies',
#  'Ananthapadmanabha, T. V.': 'Intrinsic normalization and extrinsic denormalization of formant data of vowels',
#  'Ramakrishnan, A. G.': 'Intrinsic normalization and extrinsic denormalization of formant data of vowels',
#  'Ma, Xi': 'Recognize Foreign Low-Frequency Words with Similar Pairs',
#  'Sandouk, Ubai': 'Learning Contextualized Semantics from Co-occurring Terms via a Siamese Architecture',
#  'Zhu, Fangze': 'LCSTS : A Large Scale Chinese Short Text Summarization Dataset',
#  'Zhou, Xiaoqiang': 'Answer Sequence Learning with Neural Networks for Answer Selection in Community Question Answering',
#  'Tang, Buzhou': 'Answer Sequence Learning with Neural Networks for Answer Selection in Community Question Answering',
#  'Su, Pei-Hao': 'A Benchmarking Environment for Reinforcement Learning Based Task Oriented Dialogue Management',
#  'Peng, Yangtuo': 'Leverage Financial News to Predict Stock Price Movements Using Word Embeddings and Deep Neural Networks',
#  'Gu, Jiatao': 'Non-Autoregressive Neural Machine Translation',
#  'Huang, Songfang': 'Learning with Noise : Enhance Distantly Supervised Relation Extraction with Dynamic Transition Matrix',
#  'Lin, Yiye': 'Improved Deep Speaker Feature Learning for Text-Dependent Speaker Recognition',
#  'Niu, Li-Qiang': 'Topic2Vec : Learning Distributed Representations of Topics',
#  'Dai, Xin-Yu': 'Dynamic Oracle for Neural Machine Translation in Decoding Phase',
#  'Chenthamarakshan, Vijil': 'WYSIWYE : An Algebra for Expressing Spatial and Textual Rules for Visual Information Extraction',
#  'Ma, Mingbo': 'OSU Multimodal Machine Translation System Report',
#  'Li, Shuangyin': 'Personalizing a Dialogue System with Transfer Reinforcement Learning',
#  'Li, Jiefei': 'Tag-Weighted Topic Model For Large-scale Semi-Structured Documents',
#  'Tan, Ruiyang': 'Tag-Weighted Topic Model For Large-scale Semi-Structured Documents',
#  'Vadapalli, Anandaswarup': 'Significance of Maximum Spectral Amplitude in Sub-bands for Spectral Envelope Estimation and Its Application to Statistical Parametric Speech Synthesis',
#  'Chen, Peixian': 'Document Generation with Hierarchical Latent Tree Models',
#  'Chen, Zhourong': 'Document Generation with Hierarchical Latent Tree Models',
#  'Luo, Tianyi': 'Can Machine Generate Traditional Chinese Poetry ? A Feigenbaum Test',
#  'Pabico, Jaderick P.': "On Gobbledygook and Mood of the Philippine Senate : An Exploratory Study on the Readability and Sentiment of Selected Philippine Senators ' Microposts",
#  'Dash, Niladri Sekhar': 'Automatic classification of bengali sentences based on sense definitions present in bengali wordnet',
#  'Lin, ShouXun': 'An Automatic Machine Translation Evaluation Metric Based on Dependency Parsing Model',
#  'Yan, Xu': 'Classifying Relations via Long Short Term Memory Networks along Shortest Dependency Path',
#  'Ding, Weicong': 'A Simple Approach to Learn Polysemous Word Embeddings',
#  'Li, Hanchuan': 'Visualizing NLP annotations for Crowdsourcing',
#  'Shen, Haichen': 'Visualizing NLP annotations for Crowdsourcing',
#  'Kim, Suin': 'Understanding Editing Behaviors in Multilingual Wikipedia',
#  'Park, Sungjoon': 'Understanding Editing Behaviors in Multilingual Wikipedia',
#  'Guo, Wu': 'Integrate Document Ranking Information into Confidence Measure Calculation for Spoken Term Detection',
#  'Ling, Zhen-Hua': 'A Sequential Neural Encoder with Latent Structured Description for Modeling Sentences',
#  'Amarappa, S.': "Kannada named entity recognition and classification ( nerc ) based on multinomial na\\ '' ive bayes ( mnb ) classifier",
#  'Sathyanarayana, S. V.': "Kannada named entity recognition and classification ( nerc ) based on multinomial na\\ '' ive bayes ( mnb ) classifier",
#  'Liang, Junying': 'The distribution of information content in English sentences',
#  'Zhang, Pengyuan': "Noise Robust IOA/CAS Speech Separation and Recognition System For The Third 'CHIME ' Challenge",
#  'Wang, Ziteng': 'Rank-1 Constrained Multichannel Wiener Filter for Speech Recognition in Noisy Environments',
#  'Liu, Yong': "Noise Robust IOA/CAS Speech Separation and Recognition System For The Third 'CHIME ' Challenge",
#  'Li, Xu': "Noise Robust IOA/CAS Speech Separation and Recognition System For The Third 'CHIME ' Challenge",
#  'Pang, Zaihu': "Noise-Robust ASR for the third 'CHiME ' Challenge Exploiting Time-Frequency Masking based Multi-Channel Speech Enhancement and Recurrent Neural Network",
#  'Zhu, Fengyun': "Noise-Robust ASR for the third 'CHiME ' Challenge Exploiting Time-Frequency Masking based Multi-Channel Speech Enhancement and Recurrent Neural Network",
#  'Han, Xintong': 'Selecting Relevant Web Trained Concepts for Automated Event Retrieval',
#  'Xie, Lexing': 'Describing Natural Images Containing Novel Objects with Knowledge Guided Assitance',
#  'Wei, Si': 'Natural Language Inference with External Knowledge',
#  'Law, Ritwika': 'A Novel Approach to Document Classification using WordNet',
#  'Jin, Guan-Tao': 'Textual Analysis for Studying Chinese Historical Documents and Literary Novels',
#  'Cheng, Wen-Huei': 'Color Aesthetics and Social Networks in Complete Tang Poems : Explorations and Discoveries',
#  'Zhang, Ye': 'Exploiting Domain Knowledge via Grouped Weight Sharing with Application to Text Categorization',
#  'Lee, Dongheui': 'A Preliminary Study on the Learning Informativeness of Data Subsets',
#  'Zhu, Chenhao': 'A Graph Traversal Based Approach to Answer Non-Aggregation Questions Over DBpedia',
#  'Ren, Kan': 'A Graph Traversal Based Approach to Answer Non-Aggregation Questions Over DBpedia',
#  'Wang, Haofen': 'A Graph Traversal Based Approach to Answer Non-Aggregation Questions Over DBpedia',
#  'Chen, Guoguo': 'Highway Long Short-Term Memory RNNs for Distant Speech Recognition',
#  'Zhang, Xingxing': 'Sentence Simplification with Deep Reinforcement Learning',
#  'Lin, Yiou': 'Machine Learned Resume-Job Matching Solution',
#  'Lei, Hang': 'Machine Learned Resume-Job Matching Solution',
#  'Chen, Xu': 'Multi-lingual Geoparsing based on Machine Translation',
#  'Yang, Zichao': 'Toward Controlled Generation of Text',
#  'Kwak, Son-Il': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Kown, O-Chol': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Kim, Chang-Sin': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Son, Gum-Chol': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Hwang, Chol-Jun': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Kim, Hyon-Chol': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Hyon, Gyong-Il': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Han, Sok-Min': 'A Chinese POS Decision Method Using Korean Translation Information',
#  'Liao, Yi-Hsiu': 'Towards Structured Deep Neural Network for Automatic Speech Recognition',
#  'Wu, Qi': 'Asking the Difficult Questions : Goal-Oriented Visual Question Generation via Intermediate Rewards',
#  'Zhou, Guorui': 'Hierarchical Latent Semantic Mapping for Automated Topic Generation',
#  'Hu, Ronghang': 'Natural Language Object Retrieval',
#  'Zhang, Zhongfei': 'A Deep Learning Approach for Expert Identification in Question Answering Communities',
#  'Xu, Huazhe': 'Natural Language Object Retrieval',
#  'He, Ji': 'Reinforcement Learning with External Knowledge and Two-Stage Q-functions for Predicting Popular Reddit Threads',
#  'Shen, Yikang': 'Neural Language Modeling by Jointly Learning Syntax and Lexicon',
#  'Wu, Zhengyang': 'Learning Articulated Motion Models from Visual and Lingual Signals',
#  'Noh, Hyeonwoo': 'Image Question Answering using Convolutional Neural Network with Dynamic Parameter Prediction',
#  'Han, Bohyung': 'Image Question Answering using Convolutional Neural Network with Dynamic Parameter Prediction',
#  'Jiang, Jingxiang': 'Gaussian Mixture Embeddings for Multiple Word Prototypes',
#  'Kim, Suyoun': 'Improved training for online end-to-end speech recognition systems',
#  'Lee, Moontae': 'Prior-aware Dual Decomposition : Document-specific Topic Inference for Spectral Topic Models',
#  'Thenmalar, S.': 'Semi-supervised Bootstrapping approach for Named Entity Recognition',
#  'Balaji, J.': 'Semi-supervised Bootstrapping approach for Named Entity Recognition',
#  'Geetha, T. V.': 'Semi-supervised Bootstrapping approach for Named Entity Recognition',
#  'Satish, Nadathur': 'Parallelizing Word2Vec in Shared and Distributed Memory',
#  'Kottur, Satwik': "Natural Language Does Not Emerge 'Naturally ' in Multi-Agent Dialog",
#  'Jawahar, CV': 'Fine-Grain Annotation of Cricket Videos',
#  'Yang, Yinchong': 'Learning with Memory Embeddings',
#  'Wan, Shengxian': 'Match-SRNN : Modeling the Recursive Matching Structure with Spatial RNN',
#  'Guo, Jiafeng': 'aNMM : Ranking Short Answer Texts with Attention-Based Neural Matching Model',
#  'Chen, Chengyao': 'TGSum : Build Tweet Guided Multi-Document Summarization Dataset',
#  'Zhou, Chunting': 'Multi-space Variational Encoder-Decoders for Semi-supervised Labeled Sequence Transduction',
#  'Sun, Chonglin': 'A C-LSTM Neural Network for Text Classification',
#  'Nakashole, Ndapandula': 'Machine Reading with Background Knowledge',
#  'Sun, Shangdi': 'Aspect-based Opinion Summarization with Convolutional Neural Networks',
# ...
#  'Hu, Ze': 'A deep learning approach for predicting the quality of online health expert question-answering services',
#  'Yang, Haiqin': 'A deep learning approach for predicting the quality of online health expert question-answering services',
#  'Zuo, Decheng': 'A deep learning approach for predicting the quality of online health expert question-answering services',
#  'Li, Huayu': 'A Context-aware Attention Network for Interactive Question Answering',
#  'Chao, Wenhan': 'Jointly Extracting Relations with Class Ties via Effective Deep Ranking',
#  'Luo, Zhunchen': 'Jointly Extracting Relations with Class Ties via Effective Deep Ranking',
#  'Park, Gwangbeen': 'Image-Text Multi-Modal Representation Learning by Adversarial Backpropagation',
#  'Im, Woobin': 'Image-Text Multi-Modal Representation Learning by Adversarial Backpropagation',
#  'Yu, Lang-Chi': 'Abstractive Headline Generation for Spoken Content by Attentive Recurrent Neural Networks with ASR Error Modeling',
#  'Zhang, Shi-Xiong': 'End-to-End Attention based Text-Dependent Speaker Verification',
#  'Modaresi, Pashutan': 'On ( Commercial ) Benefits of Automatic Text Summarization Systems in the News Domain : A Case of Media Monitoring and Media Response Analysis',
#  'Kuang, Da': 'Crime Topic Modeling',
#  'Shi, Haoyue': 'Real Multi-Sense or Pseudo Multi-Sense : An Approach to Improve Word Representation',
#  'Li, Caihua': 'Real Multi-Sense or Pseudo Multi-Sense : An Approach to Improve Word Representation',
#  'Bastan, Mohaddeseh': 'Neural Machine Translation on Scarce-Resource Condition : A case-study on Persian-English',
#  'Li, Maoxi': 'An entity-driven recursive neural network model for chinese discourse coherence modeling',
#  'Wang, Yifa': 'Neural Personalized Response Generation as Domain Adaptation',
#  'Zhang, Saizheng': 'Mastering the Dungeon : Grounded Language Learning by Mechanical Turker Descent',
#  'Ahmed, Waheeb': 'Question Analysis for Arabic Question Answering Systems',
#  'Lee, Teng-Yok': 'Attention-Based Multimodal Fusion for Video Description',
#  'Yun, Hyeongu': 'Efficient Transfer Learning Schemes for Personalized Language Modeling using Recurrent Neural Network',
#  'Park, Gyu-tae': 'Efficient Transfer Learning Schemes for Personalized Language Modeling using Recurrent Neural Network',
#  'Jung, Kyomin': 'Learning to Rank Question-Answer Pairs using Hierarchical Recurrent Encoder with Latent Topic Clustering',
#  'Kwak, D.': 'Fuzzy Ontology-Based Sentiment Analysis of Transportation and City Feature Reviews for Safe Traveling',
#  'Islam, S. M. Riazul': 'Fuzzy Ontology-Based Sentiment Analysis of Transportation and City Feature Reviews for Safe Traveling',
#  'Kim, K. H.': 'Fuzzy Ontology-Based Sentiment Analysis of Transportation and City Feature Reviews for Safe Traveling',
#  'Li, Zuwei': 'End-To-End Visual Speech Recognition With LSTMs',
#  'Hu, Tianran': 'Spice up Your Chat : The Intentions and Sentiment Effects of Using Emoji',
#  'Xiao, Haoyuan': 'What the Language You Tweet Says About Your Occupation',
#  'Luo, Jiebo': 'Spice up Your Chat : The Intentions and Sentiment Effects of Using Emoji',
#  'Shi, Tianlin': 'Adversarial Learning for Neural Dialogue Generation',
#  'Kamisetty, Hetunandan': 'Match-Tensor : a Deep Relevance Model for Search',
#  'Sadreddini, M. H.': 'Extracting Bilingual Persian Italian Lexicon from Comparable Corpora Using Different Types of Seed Dictionaries',
#  'Jubayer, Fazla Elahi Md': 'A Comparative Study on Different Types of Approaches to Bengali document Categorization',
#  'Luo, Hongliang': 'Topic Modeling the H\\`an di\\u { a } n Ancient Classics',
#  'Pu, Jianghuai': 'Topic Modeling the H\\`an di\\u { a } n Ancient Classics',
#  'Rose, Doori': 'Multi-level computational methods for interdisciplinary research in the HathiTrust Digital Library',
#  'Liu, Chunxi': 'Topic Identification for Speech without ASR',
#  'Zilles, Li': 'The Effect of Different Writing Tasks on Linguistic Style : A Case Study of the ROC Story Cloze Task',
#  'Zhang, Baichuan': 'Name Disambiguation in Anonymized Graphs using Network Embedding',
#  'Singh, P. D.': 'Character-level Deep Conflation for Business Data Analytics',
#  'Liu, Jialu': 'Automated Phrase Mining from Massive Text Corpora',
#  'Chintala, Soumith': 'Training Language Models Using Target-Propagation',
#  'González-Gallardo, Carlos-Emiliano': 'Efficient Social Network Multilingual Classification using Character , POS n-grams and Dynamic Normalization',
#  'Lin, Yuetan': 'Task-driven Visual Saliency and Attention-based Visual Question Answering',
#  'Pang, Zhangyang': 'Task-driven Visual Saliency and Attention-based Visual Question Answering',
#  'Zhuang, Yueting': 'Video Question Answering via Attribute-Augmented Attention Network Learning',
#  'Law, Jarvan': 'Distributed-Representation Based Hybrid Recommender System with Short Item Descriptions',
#  'Zhuo, Hankz Hankui': 'Distributed-Representation Based Hybrid Recommender System with Short Item Descriptions',
#  'Wang, Yisen': 'Residual Convolutional CTC Networks for Automatic Speech Recognition',
#  'Deng, Xuejiao': 'Residual Convolutional CTC Networks for Automatic Speech Recognition',
#  'Kang, Yongguo': 'Deep Voice : Real-time Neural Text-to-Speech',
#  'Ehsan, Upol': 'Guiding Reinforcement Learning Exploration Using Natural Language',
#  'Zhang, Ruixiang': 'Understanding Hidden Memories of Recurrent Neural Networks',
#  'Yang, Zi': 'Structural Embedding of Syntactic Trees for Machine Comprehension',
#  'Yao, Zijun': 'Discovery of Evolving Semantics through Dynamic Word Embedding Learning',
#  'Hu, Guoning': "Analyzing users ' sentiment towards popular consumer industries and brands on Twitter",
#  'Tian, Xu': 'Frame Stacking and Retaining for Recurrent Neural Network Acoustic Model',
#  'Ma, Zejun': 'Frame Stacking and Retaining for Recurrent Neural Network Acoustic Model',
#  'He, Yi': 'Frame Stacking and Retaining for Recurrent Neural Network Acoustic Model',
#  'Wei, Juan': 'Frame Stacking and Retaining for Recurrent Neural Network Acoustic Model',
#  'Zhang, Xiao-gang': 'A Novel Comprehensive Approach for Estimating Concept Semantic Similarity in WordNet',
#  'Sun, Shou-qian': 'A Novel Comprehensive Approach for Estimating Concept Semantic Similarity in WordNet',
#  'Zhang, Ke-jun': 'A Novel Comprehensive Approach for Estimating Concept Semantic Similarity in WordNet',
#  'Lim, Lynn-Li': 'English Conversational Telephone Speech Recognition by Humans and Machines',
#  'Lin, Zhouhan': 'Neural Language Modeling by Jointly Learning Syntax and Lexicon',
#  'Shehnepoor, Saeedreza': 'NetSpam : a Network-based Spam Detection Framework for Reviews in Online Social Media',
#  'Tang, Ruiming': 'DeepFM : A Factorization-Machine based Neural Network for CTR Prediction',
#  'Ye, Yunming': 'DeepFM : A Factorization-Machine based Neural Network for CTR Prediction',
#  'He, Xiuqiang': 'DeepFM : A Factorization-Machine based Neural Network for CTR Prediction',
#  'Zhang, Junbei': 'Exploring Question Understanding and Adaptation in Neural-Network-Based Question Answering',
#  'Hirata, Ai': 'Sparse Named Entity Classification using Factorization Machines',
#  'Ma, Ji': 'Natural Language Processing with Small Feed-Forward Networks',
#  'Do, Phong-Khac': 'Legal Question Answering using Ranking SVM and Deep Convolutional Neural Network',
#  'Jang, Myungha': 'Improving Document Clustering by Eliminating Unnatural Language',
#  'Meng, Yuanliang': 'Temporal Information Extraction for Question Answering Using Syntactic Dependencies in an LSTM-based Architecture',
#  'Li, Wenpeng': 'Empirical Evaluation of Parallel Training Algorithms on Acoustic Modeling',
#  'Tsai, Yao-Hung Hubert': 'Learning Robust Visual-Semantic Embeddings',
#  'Huang, Liang-Kang': 'Learning Robust Visual-Semantic Embeddings',
#  'Arguelles, Jonito Aerts': 'Towards a Quantum World Wide Web',
#  'Zhang, Jingqing': 'I2T2I : Learning Text to Image Synthesis with Textual Data Augmentation',
#  'Wu, Peihao': 'Deep LSTM for Large Vocabulary Continuous Speech Recognition',
#  'Situ, Wenchang': 'Deep LSTM for Large Vocabulary Continuous Speech Recognition',
#  'Esteban, J. L.': 'Are crossing dependencies really scarce ?',
#  'Wu, Joy T.': 'Comparing Rule-Based and Deep Learning Models for Patient Phenotyping',
#  'Claes, Maëlick': 'Bootstrapping a Lexicon for Emotional Arousal in Software Engineering',
#  'Lu, Yichao': 'A practical approach to dialogue response generation in closed domains',
#  'Zhang, Shaonan': 'A practical approach to dialogue response generation in closed domains',
#  'Skerry-Ryan, RJ': 'Natural TTS Synthesis by Conditioning WaveNet on Mel Spectrogram Predictions',
#  'Yang, Zongheng': 'Natural TTS Synthesis by Conditioning WaveNet on Mel Spectrogram Predictions',
#  'Liu, Haixia': 'Sentiment Analysis of Citations Using Word2vec',
#  'Ramgoolam, Sanjaye': 'Linguistic Matrix Theory',
#  'Shopon, Md': 'BanglaLekha-Isolated : A Comprehensive Bangla Handwritten Character Dataset',
#  'Qin, Lianhui': 'Adversarial Connective-exploiting Networks for Implicit Discourse Relation Classification',
#  'Park, Jaehong': 'Building a Neural Machine Translation System Using Only Synthetic Parallel Data',
#  'Song, Jongyoon': 'Building a Neural Machine Translation System Using Only Synthetic Parallel Data',
#  'Liu, Lu-chen': 'Syntax Aware LSTM Model for Chinese Semantic Role Labeling',
#  'Hwang, Hsin-Te': 'Voice Conversion from Unaligned Corpora using Variational Autoencoding Wasserstein Generative Adversarial Networks',
#  'Wu, Yi-Chiao': 'Voice Conversion from Unaligned Corpora using Variational Autoencoding Wasserstein Generative Adversarial Networks',
#  'Tsao, Yu': 'Voice Conversion from Unaligned Corpora using Variational Autoencoding Wasserstein Generative Adversarial Networks',
#  'Zhang, Tianyang': 'Emotional Chatting Machine : Emotional Conversation Generation with Internal and External Memory',
#  'Bao, Hangbo': 'Neural Question Generation from Text : A Preliminary Study',
#  'Tang, Yi-Kun': 'Conceptualization Topic Modeling',
#  'Huang, Heyan': 'Conceptualization Topic Modeling',
#  'Zhang, Yaoyuan': 'A Constrained Sequence-to-Sequence Neural Model for Sentence Simplification',
#  'Xu, Anbang': '25 Tweets to Know You : A New Model to Predict Personality with Social Media',
#  'Zhang, Mengdi': 'Fostering User Engagement : Rhetorical Devices for Applause Generation Learnt from TED Talks',
#  'Aeron, Shuchin': 'Word Embeddings via Tensor Factorization',
#  'Ren, Pengjie': 'Entity Linking for Queries by Searching Wikipedia Sentences',
#  "Huang, Ting-Hao 'Kenneth'": 'Evorus : A Crowd-powered Conversational Assistant Built to Automate Itself Over Time',
#  'Du, Shujing': 'An entity-driven recursive neural network model for chinese discourse coherence modeling',
#  'Long, Zi': 'Translation of Patent Sentences with a Large Vocabulary of Technical Terms Using Neural Machine Translation',
#  'Mitsuhashi, Tomoharu': 'Translation of Patent Sentences with a Large Vocabulary of Technical Terms Using Neural Machine Translation',
#  'Wang, Su': 'Leveraging Discourse Information Effectively for Authorship Attribution',
#  'Lee, Guang-He': 'MUSE : Modularizing Unsupervised Sense Embeddings',
#  'Lai, Guokun': 'Large-scale Cloze Test Dataset Designed by Teachers',
#  'Rajendran, S': 'Dependency resolution and semantic mining using Tree Adjoining Grammars for Tamil Language',
#  'Anandkumar, M': 'Dependency resolution and semantic mining using Tree Adjoining Grammars for Tamil Language',
#  'Jiang, Youxuan': 'Understanding Task Design Trade-offs in Crowdsourced Paraphrase Collection',
#  'Su, Yu': 'Cross-domain Semantic Parsing via Paraphrasing',
#  'Hu, Wenpeng': 'Neural System Combination for Machine Translation',
#  'Kim, Gunhee': 'A Read-Write Memory Network for Movie Story Understanding',
#  'Lee, Hongrae': 'Learning to Skim Text',
#  'Zhao, Sanqiang': 'Deep Keyphrase Generation',
#  'Chi, Yu': 'Deep Keyphrase Generation',
#  'Zhao, Li': 'Adversarial Neural Machine Translation',
#  'Lai, Jianhuang': 'Adversarial Neural Machine Translation',
#  'Wu, Yongjian': 'Fast and Accurate Neural Word Segmentation for Chinese',
#  'Hu, Hexiang': 'Being Negative but Constructively : Lessons Learnt from Creating Better Visual Question Answering Datasets',
#  'Chen, Yanging': 'Detecting English Writing Styles For Non Native Speakers',
#  'Singh, Ritambhara': 'GaKCo : a Fast GApped k-mer string Kernel using COunting',
#  'Wang, Beilun': 'GaKCo : a Fast GApped k-mer string Kernel using COunting',
#  'Zaheer, Manzil': 'Go for a Walk and Arrive at the Answer : Reasoning Over Paths in Knowledge Bases using Reinforcement Learning',
#  'Yan, Xinru': "Who 's to say what 's funny ? A computer using Language Models and Deep Learning , That 's Who !",
#  'Shao, Junru': 'Learning to Ask : Neural Question Generation for Reading Comprehension',
#  'Niu, Shuzi': 'DailyDialog : A Manually Labelled Multi-turn Dialogue Dataset',
#  'Zhou, Ganbin': 'Tree-Structured Neural Machine for Linguistics-Aware Sentence Generation',
#  'Cao, Rongyu': 'Tree-Structured Neural Machine for Linguistics-Aware Sentence Generation',
#  'Dai, Dengxin': 'Object Referring in Visual Scene with Spoken Language',
#  'Guo, Ruiqi': 'Efficient Natural Language Response Suggestion for Smart Reply',
#  'Zhu, Danhao': 'Going Wider : Recurrent Neural Network With Parallel Cells',
#  'Shen, Si': 'Going Wider : Recurrent Neural Network With Parallel Cells',
#  'Xu, Ruochen': 'Cross-lingual Distillation for Text Classification',
#  'Li, Mengxue': 'Using Argument-based Features to Predict and Analyse Review Helpfulness',
#  'Geng, Shiqiang': 'Using Argument-based Features to Predict and Analyse Review Helpfulness',
#  'Li, Minglan': 'Using Argument-based Features to Predict and Analyse Review Helpfulness',
#  'Abuhay, Tesfamariam M.': 'Analysis of Computational Science Papers from ICCS 2001-2016 using Topic Modeling and Graph Theory',
#  'Ma, Xiaokong': 'Deep Speaker : an End-to-End Neural Speaker Embedding System',
#  'Lu, Le': 'NegBio : a high-performance tool for negation and uncertainty detection in radiology reports',
#  'Fu, Gengshen': 'Max-Pooling Loss Training of Long Short-Term Memory Networks for Small-Footprint Keyword Spotting',
#  'Lamba, Hemank': 'Item Recommendation with Evolving User Preferences and Experience',
#  'Hu, Minghao': 'Reinforced Mnemonic Reader for Machine Comprehension',
#  'Wu, Qingbo': 'Drug-drug Interaction Extraction via Recurrent Neural Network with Multiple Attention Layers',
#  'Qin, Zengchang': 'Text Generation Based on Generative Adversarial Nets with Latent Variable',
#  'Zhang, Jiyuan': 'Flexible and Creative Chinese Poetry Generation Using Neural Memory',
#  'Luo, Bingfeng': 'Learning to Predict Charges for Criminal Cases with Legal Basis',
#  'Zhu, Zhanxing': 'Learning with Noise : Enhance Distantly Supervised Relation Extraction with Dynamic Transition Matrix',
#  'Jun, Heewoo': 'Robust Speech Recognition Using Generative Adversarial Networks',
#  'Nair, Surag': 'A Biomedical Information Extraction Primer for NLP Researchers',
#  'Song, Le': 'Variational Reasoning for Question Answering with Knowledge Graph',
#  'Aphinyanaphongs, Yindalon': 'Utility of general and specific word embeddings for classifying translational stages of research',
#  'Wang, Zhengyang': 'Learning Convolutional Text Representations for Visual Question Answering',
#  'Ji, Shuiwang': 'Learning Convolutional Text Representations for Visual Question Answering',
#  'Liu, Jingzhou': 'Softmax Q-Distribution Estimation for Structured Prediction : A Theoretical Interpretation for RAML',
#  'Vidal, Maria-Esther': 'Use of Knowledge Graph in Rescoring the N-Best List in Automatic Speech Recognition',
#  'Wang, Zhengkui': 'TwiInsight : Discovering Topics and Sentiments from Social Media Datasets',
#  'Xu, Quanqing': 'TwiInsight : Discovering Topics and Sentiments from Social Media Datasets',
#  'Nikolsky, Yuri': "Increasing Papers ' Discoverability with Precise Semantic Labeling : the sci.AI Platform",
#  'Jin, Wengong': 'Deriving Neural Architectures from Sequence and Graph Kernels',
#  'Xie, Zhipeng': 'Max-Cosine Matching Based Neural Models for Recognizing Textual Entailment',
#  ...}

# %%
with open("names.csv","w") as f:
    for auth, title in my_new_unk_n_papers.items():
        if is_initials(auth):
            continue
        f.write(auth.replace(",",";")+"\t"+pp[auth]+"\n")

# %%
len(my_new_unk) / len(all_auths)
# Out:
# 0.1104212116126867

# %%
unk = set()
for auth in authors:
    auth = auth.strip()
    if auth in known_f or auth in known_m:
        continue
    else:
        unk.add(auth)

# %%
len(authors)
# Out:
# 7

# %%
len(unk)
# Out:
# 0

# %%
len(my_new_unk)
# Out:
# 1316

# %%
from collections import defaultdict
male_last_names = defaultdict(list)
for name in known_m:
    if len(name.split(", ")) < 2:
        print(name)
        continue
    last, first = name.split(", ")
    male_last_names[last].append(first)
    
female_last_names = defaultdict(list)
for name in known_f:
    if len(name.split(", ")) < 2:
        print(name)
        continue
    last, first = name.split(", ")
    female_last_names[last].append(first)
# Out:
# Robert

# %%
# Out:
# ['Kirchmeier-Andersen,']
# ['Barbara']
# ['Eklund,']
# ['Di Eugenio,']
# ['Sabine']

# %%
a = set()
a.add("B")
a.add("C")
b = set()
b.add("C")
b.add("B")
a==b
# Out:
# True

# %%
def init_match(inits, name):
    inits.replace("Dr.","")
    inits_split = inits.split(" ")
    name_split = name.split(" ")
    if len(inits_split) == len(name_split):
        match = True
        for idx, i in enumerate(inits_split):
            if i.strip()[0] != name_split[idx].strip()[0]:
                match = False
        if match == True:
            return 1 #confident match
    if inits[0] == name_split[0]:
        return 2 # maybe match
    inits_set = set()
    name_set = set()
    for letter in inits:
        if letter.isupper():
            inits_set.add(letter)
    for letter in name_set:
        if letter.isupper():
            name_set.add(letter)
    if inits_set == name_set:
        return 1 # confident match
    for letter in inits_set:
        if letter in name_set:
            return 3 # maybee
    return 0 #no match

# %%
#tests
print(match("M. R.", "Morgan R."))
# Out:
# 1

# %%
i = 0
j = 0
k = 0
for name in just_initials:
    if len(name.split(", ")) < 2:
        #print(name)
        continue
    last, first = name.split(", ")
    m = last in male_last_names
    f = last in female_last_names
    if m and not f:
        names = male_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                print(name, "===", n)
                known_m.add(name)
                i += 1
                break
       
    if f and not m:
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                #print(name, "===", n)
                known_f.add(name)
                j += 1
                break
    if f and m:
        
        match_f = 0
        match_m = 0
        names = male_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_m):
                match_m = mtch
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_f):
                match_f = mtch
        if match_f > match_m:
            k+=1
            known_m.add(name)
        if match_m > match_f:
            k+=1
            known_f.add(f)
            
print(i, "sure males")    
print(j, "sure females")
print(k, "probably")
# Out:
# Backofen, R. === Rolf
# Lopez-Gazpio, I. === Iñigo
# Tur, G. === Gokhan
# Besacier, L. === Laurent
# Chicoisne, G. === Guillaume
# El-Shishtawy, T. === Tarek
# Gerow, A. === Aaron
# Neumann, G. === Guenter
# Marquez, L. === Lluis
# Bentz, C. === Chris
# Stamatopoulos, P. === Panagiotis
# Androutsopoulos, I. === Ion
# Spyropoulos, C. D. === Constantine D.
# Dodds, P. S. === Peter Sheridan
# Lopes, A. === António
# Danforth, C. M. === Christopher M.
# Thompson, C. === Christopher
# Agirre, E. === Eneko
# McMahon, M. T. === Matthew T.
# Daelemans, W. === Walter
# Paliouras, G. === George
# Adhikari, R. === Ronojoy
# Stone, M. === Matthew
# Yvon, F. === Francois
# Utiyama, M. === Masao
# Petroni, F. === Filippo
# Chenfour, N. === Noureddine
# Padro, L. === Lluis
# Keane, M. T. === Mark T.
# Mueller, M. === Martin
# Bagrow, J. P. === James P.
# Sangal, R. === Rajeev
# Kryssanov, V. V. === Victor V.
# Benjumea, J. === Juan
# Goodman, B. === Benjamin
# Kwak, K. S. === Kyung Sup
# Allahverdyan, A. E. === Armen E.
# Lande, D. === Dmitry
# Agnes, F. === Frederic
# Semple, S. === Stuart
# Kromer, V. === Victor
# Lafferty, J. === John
# Schwab, D. === Didier
# Ferrero, J. === Jeremy
# Soman, K. P. === K P
# Reyle, U. === Uwe
# Schommer, C. === Christoph
# Brill, E. === Eric
# Artola, X. === Xabier
# Goerz, G. === Guenther
# Agoramoorthy, G. === Govindasamy
# Zweig, G. === Geoffrey
# Molla, D. === Diego
# Tivnan, B. F. === Brian F.
# Guru, D. S. === D S
# Laporte, E. === Eric
# Niemann, H. === Heinrich
# Maurel, D. === Denis
# Serva, M. === Maurizio
# Kestemont, M. === Mike
# Reiter, E. === Ehud
# Bruza, P. D. === Peter D.
# Arregi, X. === Xabier
# Arora, R. === Raman
# Isahara, H. === Hitoshi
# Ueberla, J. P. === Joerg P.
# Jurafsky, D. === Dan
# Gallwitz, F. === Florian
# Harnad, S. === Stevan
# Seide, F. === Frank
# Becker, M. === Martin
# Karkaletsis, V. === Vangelis
# Uchimoto, K. === Kiyotaka
# Clark, E. M. === Eric M.
# Nagao, M. === Makoto
# Palomar, M. === Manolo
# Laprie, Y. === Yves
# Murata, M. === Masaki
# Petasis, G. === Georgios
# Alegria, I. === Iñaki
# Hernández-Fernández, A. === Antoni
# Marazzato, R. === Roberto
# Gargouri, Y. === Yassine
# Ragel, R. G. === Roshan G.
# Morin, E. === Emmanuel
# Pustejovsky, J. === James
# Sarasola, K. === Kepa
# Picard, O. === Olivier
# Daume, H. === Hal
# Sakkis, G. === Georgios
# Droppo, J. === Jasha
# Reagan, A. J. === Andrew J.
# Ferrer-i-Cancho, R. === Ramon
# Stolcke, A. === Andreas
# Dale, R. === Robert
# Marcu, D. === Daniel
# Lascarides, A. === Alex
# Hanrieder, G. === Gerhard
# Hess, M. === Michael
# Koroutchev, K. === Kostadin
# Rigau, G. === German
# 101 sure males
# 20 sure females
# 23 probably

# %%
known_m.

# %%
import os
from enum import Enum
import pandas as pd
import re
import numpy as np
from collections import Counter
import html
import matplotlib.pyplot as plt
import seaborn as sns
from metadata.metadata import ACL_metadata
from metadata import Gender
from collections import defaultdict
from itertools import chain

# %matplotlib inline

# %%
unk
# Out:
# {'Filho, Demival Vasques',
#  'R, Kanagavalli V',
#  'Lee, Sang-goo',
#  'Li, Xiao-li',
#  'Beltagy, I.',
#  'Walker, M. A.',
#  'Yang, Zhenglu',
#  'Zhang, Huimin',
#  'Bastan, Mohadeseh',
#  'Karray, H.',
#  'Zhai, Chengxiang',
#  'Annervaz, K. M.',
#  'Martinez-Barco, P.',
#  'Stamatopoulos, P.',
#  'Sunitha, Dr K. V. N.',
#  'Ferrero, J.',
#  'Yao, Y.',
#  'Chen, Kehai',
#  'Mitra, Rajarshee',
#  'Pabico, Jaderick P.',
#  'Xiao, Xiong',
#  'Ferrer-i-Cancho, R.',
#  'Hsu, M. J.',
#  'Eklund,',
#  'Pustejovsky, J.',
#  'Liu, Hairong',
#  'Zhang, Xi',
#  'Petroni, F.',
#  'Hu, Wenbo',
#  'Hong, Liangjie',
#  'Semple, S.',
#  'Chen, Danlu',
#  'Trivedi, Priyansh',
#  'Wei, Si',
#  'Sun, Chonglin',
#  'Ehsan, Upol',
#  'Geng, Shiqiang',
#  'Su, Hang',
#  'Lu, Hsiang-Hung',
#  'Ouyang, Sixun',
#  'Wu, L.',
#  'Cho, Sungzoon',
#  'Nair, Surag',
#  'Wang, Hongsu',
#  'Luo, Juan',
#  'Yan, Shuicheng',
#  'Yang, Baosong',
#  'Tivnan, B. F.',
#  'Seo, Minjoon',
#  'Utiyama, M.',
#  'Marazzato, R.',
#  'Bar-Yam, Yaneer',
#  'Berri, J.',
#  'Achary, K. K.',
#  'Wang, Chunqi',
#  'Wadhawan, Kahini',
#  'Ganesh, J',
#  'Herath, P.',
#  'Lu, Jiasen',
#  'Deng, Weibing',
#  'Lee, Jeehye',
#  'Chi, Yu',
#  'He, Yong',
#  'Dente, J. A.',
#  'Huang, Po-Sen',
#  'Amin, M. R.',
#  'Maritxalar, M.',
#  'Tatar, D.',
#  'Lusseau, D.',
#  'Springmann, U.',
#  'Sung, Wonyong',
#  'Bollepalli, Bajibabu',
#  'Li, Haoxiang',
#  'Jia, Xianyan',
#  'Tamara, Tretjakova',
#  'Hwang, Chol-Jun',
#  'Mueller, M.',
#  'Singh, Ritambhara',
#  'Chen, Haohui',
#  'Liang, Yingyu',
#  'Cai, Pengshan',
#  'Galves, A.',
#  'Huang, Xuangjing',
#  'Ritchie, G. D.',
#  'Yan, Erjia',
#  'Yoo, Jaeyoon',
#  'Chen, Xilun',
#  'Hu, Jinghe',
#  'Yvon, F.',
#  'Li, Juliang',
#  'Gojenola, K.',
#  'Liu, Xipei',
#  'Laros, J. F. J.',
#  'Gilkey, P.',
#  'Srinivas, B.',
#  'Gillet, J.',
#  'Lin, Zhouhan',
#  'Luo, Hongliang',
#  'Khan, M. A.',
#  'Xie, Ruobing',
#  'Steven, Du',
#  'Chen, Chien-Ying',
#  'Mitchell, L.',
#  'Adda-Decker, M.',
#  'Zaidan, B. B',
#  'Liu, Tie-Yan',
#  'Seltzer, M.',
#  'Qin, Zengchang',
#  'Wang, Xiuli',
#  'Sureka, K.',
#  'Volchenkov, D.',
#  'Wen, Yicheng',
#  'Dodds, P. S.',
#  'Lascarides, A.',
#  'Jung, Changwoo',
#  'Benjumea, J.',
#  'Boros, M.',
#  'Wang, Dingquan',
#  'Keane, M. T.',
#  'Murata, M.',
#  'Homayon, Sheideh',
#  'Fu, King-wa',
#  'Ren, Xuancheng',
#  'Ma, Tengyu',
#  'Ding, Yanzhuo',
#  'Kim, Ho-Gyeong',
#  'Kwak, D.',
#  'Virdee, Kawandeep',
#  'Kloumann, I. M.',
#  'Alzhrani, Khudran',
#  'Clark, E. M.',
#  'Ahn, Ae-Lim',
#  'Sun, Zequn',
#  'Joo, Jungseock',
#  'Zhu, Zhanxing',
#  'Zhao, Sanqiang',
#  'Sun, Hanwu',
#  'Hsu, I-Hung',
#  'Lee, Gichang',
#  'Jin, Guan-Tao',
#  'Khan, Md. Farukuzzaman',
#  'Wang, Jinzhao',
#  'Ma, Xi',
#  'Peng, Haoruo',
#  'Yang, Haiqin',
#  'Choi, Keunwoo',
#  'Chi, Lianhua',
#  'Yan, Weipeng P.',
#  'Lüdeling, A.',
#  'Guo, Wu',
#  'Lyu, Yajuan',
#  'Rao, R. Rajeswara',
#  'Li, B.',
#  'Droppo, J.',
#  'Wang, Ziteng',
#  'Han, Sok-Min',
#  'Jiang, Jingchi',
#  'Claes, Maëlick',
#  'Wang, ZiYun',
#  'Tahirovic, E.',
#  'Borge, J.',
#  'Chen, Zhourong',
#  'Rahman, Md. Mijanur',
#  'Lin, Yiye',
#  'Zilles, Li',
#  'Karyakin, Yuri',
#  'Suleman, Kaheer',
#  'Chicoisne, G.',
#  'Meelu, Kshitijh',
#  'Orife, Iroro',
#  'Lei, Hang',
#  'Chowdhury, Md. Naseef-Ur-Rahman',
#  'Shan, Zifei',
#  'Ji, Zongcheng',
#  'Wolff, J Gerard',
#  'Song, Peiyou',
#  'Xu, Yi-Zhi',
#  'Xie, Sihong',
#  'Chen, Zeyu',
#  'Cai, Ruichu',
#  'Zhu, Chenguang',
#  'Manjari, M.',
#  'Liu, Xianggen',
#  'Chen, Xingyue',
#  'Jose, Chinchu',
#  'Singla, Mausam',
#  'Thenmalar, S.',
#  'Jin, Yaohui',
#  'Zhao, He',
#  'Lu, Yen-Ju',
#  'Jang, Chung-Hyok',
#  'Yuan, Fajie',
#  'Agrawaal, Taneea S',
#  'Shao, Junru',
#  'Zhou, Xiyou',
#  'Morin, E.',
#  'Zhu, Linhong',
#  'Della Pietra, V.',
#  'Skerry-Ryan, RJ',
#  'Huang, Kejun',
#  'Tay, Yi',
#  'Wan, Mengting',
#  'Khiari, Raoum',
#  'Yoon, Sungroh',
#  'Dhanalakshmi, V.',
#  'Zhao, Chenghui',
#  'Koroutchev, K.',
#  'Lee, Hongrae',
#  'Azzeddine, Mazroui',
#  'Manin, Yuri',
#  'Esteban, J. L.',
#  'Chen, Yang-De',
#  'Xia, Yingce',
#  'Yao, Li',
#  'van Rijsbergen, C. J.',
#  'Jiffriya, M. A. C.',
#  'Marcotte, O.',
#  'Wang, Suhang',
#  'Shi, Haoran',
#  'Montoyo, A.',
#  'Jalab, Hamid. A.',
#  'Chen, Weichao',
#  'Cetoli, A.',
#  'Vishwanathan, S. V. N.',
#  'Ai, Qingyao',
#  'Ling, Zhen-Hua',
#  'Huang, Liusheng',
#  'Wang, Zhengyang',
#  'Barbara',
#  'Wang, Wenhan',
#  'Malakar, Mancha Jyoti',
#  'Litkowski, K.',
#  'Li, Yuezhang',
#  'Lande, D.',
#  'Braun, C.',
#  'Zhu, Qi',
#  'Lopez-Gazpio, I.',
#  'Zhang, Byoung-Tak',
#  'Korutcheva, E.',
#  'Sadreddini, M. H.',
#  'Zhang, Jiawan',
#  'Sun, Yizhou',
#  'Thompson, C.',
#  'Cheng, Jianpeng',
#  'Kiamarzpour, Foruzan',
#  'Kim, Taesup',
#  'Kim, Jonggu',
#  'Lai, Liangzhen',
#  'Bandyopadhyay, Bortik',
#  'Zheng, Daqi',
#  'Hu, Zhiting',
#  'Pang, Zaihu',
#  'de Gussem, J.',
#  'Kromer, V.',
#  'Pu, Jianghuai',
#  'Zhang, Baichuan',
#  'Dai, Zihang',
#  'Huang, X.',
#  'Mun, Seongkyu',
#  'Huang, Xuanjing',
#  'Kim, Kwang-Hyok',
#  'Liu, Sa',
#  'Huang, Yi-Yao',
#  'Balaraman, Vevake',
#  'Besacier, L.',
#  'Chen, Geliang',
#  'Yan, Zhao',
#  'Schommer, C.',
#  'Suarez, A.',
#  'Chen, Weizheng',
#  'Fan, Zhengping',
#  'Padro, L.',
#  'Yan, Xu',
#  'Wang, Shuohang',
#  'Huang, Songfang',
#  'Jin, Panshi',
#  'Hiranandani, Gaurush',
#  'Wen, Ji',
#  'Arbib, M. A.',
#  'Niyogi, Mitodru',
#  'Sabbir, A. K. M.',
#  'Zhou, Li',
#  'Choi, Jeung-Yoon',
#  'Shen, Gehui',
#  'Paun, D.',
#  'Yu, Chengzhu',
#  'Li, Shang-Wen',
#  'Narayanan, PJ',
#  'Jubayer, Fazla Elahi Md',
#  'Hu, Tianran',
#  'Hirata, Ai',
#  'Dai, Zhuyun',
#  'Zuo, Decheng',
#  'Evans, R. J.',
#  'Shi, Baoxu',
#  'Su, Huey-Jen',
#  'Ma, Ji',
#  'Zanon-Boito, M.',
#  'Ke, J-Y',
#  'Jiang, Jingxiang',
#  'Shehnepoor, Saeedreza',
#  'Viji, P. Abinaya',
#  'Kim, Taeuk',
#  'Li, Boyang',
#  'Ye, Yunming',
#  'Zhukov, T. A.',
#  'Tupper, P. F.',
#  'Zhang, Jinglan',
#  'Liu, Da-Rong',
#  'Wu, Zeqiu',
#  'LI, Hang',
#  'Wang, Zhengkui',
#  'Kwak, Son-Il',
#  'Zen, Heiga',
#  'Jo, Hwiyeol',
#  'Lamel, L.',
#  'Yeung, Dit-Yan',
#  'Huang, Che-Wei',
#  'Singh, P. D.',
#  'Daume, H.',
#  'Munigala, Vitobha',
#  'Jang, Myungha',
#  'Boutahar, J.',
#  'Niu, Li-Qiang',
#  'Bharathi, Prof. H. N.',
#  'He, Ji',
#  'Alimi, A. M.',
#  'Kim, Suin',
#  'Komiya, Jiyu',
#  'Zhang, Xueliang',
#  'Ahmed, Rasyan',
#  'Castro, Dani',
#  'Manuel, Rebuschi',
#  'Kim, Sangeok',
#  'Dai, Yinpei',
#  'Sloan, M.',
#  'Molla, D.',
#  'Ramesh, Palghat',
#  'Lee, Teng-Yok',
#  'Kim, Geunbae Lee Jong-Hyeok Lee Kyunghee',
#  'Mitsuhashi, Tomoharu',
#  'Ahn, Yong-Yeol',
#  'Kwak, K. S.',
#  'He, Di',
#  'S, Sreelekha.',
#  'Zhan, Yiqiang',
#  'Lee, Kong Aik',
#  'Chen, Zhenxiang',
#  'Stueker, S.',
#  'Iordanidou, A.',
#  'Zhang, Yaoyuan',
#  'Eckert, W.',
#  'Chen, Yanging',
#  'Kossinets, Gueorgi',
#  'Yang, Daylen',
#  'Qi, Hang',
#  'Collet, P.',
#  'Yang, Shan',
#  'Li, Minglan',
#  'Li, Wentian',
#  'Giuliani, A.',
#  'Beheshti, Seyed-Mehdi-Reza',
#  'Wu, Qi',
#  'Arenas, A.',
#  'Song, Inchul',
#  'Anoop, V. S.',
#  'Oh, J.',
#  'Tian, Yuandong',
#  'Park, Sungjoon',
#  'Lim, Lynn-Li',
#  'Li, Chenliang',
#  'Shen, Sheng-syun',
#  'Seol, Jinseok',
#  'Huangfu, Luwen',
#  'Arguelles, Jonito Aerts',
#  'Goerz, G.',
#  'Bentz, C.',
#  'Zhang, Shiyue',
#  'Siddharth, N.',
#  'Gordienko, Yuri',
#  'Meghawat, Aaksha',
#  'Law, Ritwika',
#  'Yan, Xinru',
#  'LanJun, Zhou',
#  'Ling, Mingyang',
#  'Ko, Hanseok',
#  'Rajendran, S.',
#  'Divakaran, Sajilal',
#  'Huang, Liang-Kang',
#  'Li, Ya',
#  'Wu, Ke',
#  'Gong, Yongen',
#  'Liu, Jingen',
#  'Wei, Bingzhen',
#  'Paliouras, G.',
#  'Zhang, Junbei',
#  'Lin, Xixun',
#  'Martin, R.',
#  'Meng, Yuanliang',
#  'Al-Mehairi, Yaared',
#  'Seo, Seungwan',
#  'Sugimoto, Go',
#  'Kharde, Vishal. A.',
#  'Li, Yanpeng',
#  'Shi, Qiuhui',
#  'Sharma, A. K.',
#  'Xie, Lexing',
#  'Tan, Ruiyang',
#  'Rialland, A.',
#  'Pan, Yingwei',
#  'Choi, Sanghyuk',
#  'Hu, Mengke',
#  'Smirnov, A. V.',
#  'Burman, Amev',
#  'Mysore, Sheshera',
#  "O'Harney, A. D.",
#  'James, A. P.',
#  'Shen, Yelong',
#  'Sharmiladevi, V.',
#  'Rajan, K.',
#  'Kestemont, M.',
#  'Xu, Xinnuo',
#  'Do, Phong-Khac',
#  'Karkaletsis, V.',
#  'Kim, Minseok',
#  'Sandanalakshmi, R.',
#  'Yang, Shuang-Hong',
#  'Katti, S. K.',
#  'Anh, L. T.',
#  'Seguin, C.',
#  'Chen, Wenhu',
#  'Chen, Mingcheng',
#  'de Gispert, Adri`a',
#  'Su, Tzu-Ray',
#  'Lee, Won-Sook',
#  'Feng, Yi',
#  'Yih, Wen-tau',
#  'Liu, Lu-chen',
#  'Lapata, M.',
#  'Jun, Heewoo',
#  'Li, Ji',
#  'Wu, Joy T.',
#  'Thakare, VM',
#  'Petasis, G.',
#  'Becker, M.',
#  'Gao, Haoyuan',
#  'Daille, B.',
#  'Liu, Xiaomo',
#  'Wang, Zhaowen',
#  'El-Shishtawy, T.',
#  'Hanane, Tebbi',
#  'Liu, Lingqiao',
#  'Li, Rumeng',
#  'Kim, Jaebok',
#  'Mao, Huina',
#  'Kim, Chang-Sin',
#  'Castano, J.',
#  'Godard, P.',
#  'Artola, X.',
#  'Sra, Suvrit',
#  'Wu, Peihao',
#  'Xiao, Bo',
#  'Pagel, V.',
#  'Marian, Zsuzsana',
#  'Hashem, M. M. A.',
#  'Song, Yangqiu',
#  'Huang, Wei-Jie',
#  'He, Yuxiong',
#  'Xiao, Yanghua',
#  'Hanrieder, G.',
#  'Chen, Chengyao',
#  'Aeron, Shuchin',
#  'Liu, Zhuoran',
#  'Lee, Haejun',
#  'Wang, Yuanzhuo',
#  'Popescul, Alexandrin',
#  'Lamba, Hemank',
#  'Park, Gyu-tae',
#  'Rahul, Patchigolla V S S',
#  'Hou, Shufen',
#  'Hu, Baotian',
#  'Yang, Dejian',
#  'Haque, Md. Masudul',
#  'Almishari, Mishari',
#  'Liao, Yi',
#  'Jayaweera, A. J. P. M. P.',
#  'Ge, Qi',
#  'Zhang, Xingxing',
#  'Amine, Chennoufi',
#  'Choe, Changil',
#  'Liu, Haixia',
#  'Lin, Huei-Chi',
#  'Wu, Fuxiang',
#  'Miram, G. E.',
#  'Sun, Haoze',
#  'Li, Guohao',
#  'Liu, Jiayi',
#  'Jawahar, CV',
#  'Reagan, A. J.',
#  'Yanyan, Zhao',
#  'Rizoiu, Marian-Andrei',
#  'Dash, Niladri Sekhar',
#  'Zhang, Renxian',
#  'Wang, Xi',
#  'Sculley, D.',
#  'Zhou, Tianyi',
#  'Bedi, Harsimran',
#  'Serva, M.',
#  'Pan, Shirui',
#  'Zhang, Yongfeng',
#  'Sukhbaatar, Sainbayar',
#  'Reinanda, R.',
#  'Wu, Yuexin',
#  'Ramos-Soto, A.',
#  'Wang, Qinlong',
#  'McMahon, M. T.',
#  'Vadapalli, Anandaswarup',
#  'Jung, Kyomin',
#  'Huang, Kanyi',
#  'Yang, Guandao',
#  'Jose, Joemon M.',
#  'Park, Juyong',
#  'Balamurali, A. R.',
#  'He, Xuanli',
#  'Ferrandez, A.',
#  'Bhatia, Shraey',
#  'Deng, Yuntian',
#  'Chen, Ruey-Cheng',
#  'Robertson, R.',
#  'Adhikari, R.',
#  'Li, Mengxue',
#  'Tang, Gongbo',
#  'Cao, Shaozu',
#  'Zhuang, Yueting',
#  'Xiong, W.',
#  'Shams, Rushdi',
#  'He, Xiuqiang',
#  'Nelson, D.',
#  'Sabine',
#  'Kakusho, K.',
#  'Neumann, G.',
#  'Bragaglia, S.',
#  'Indurthi, Vijayasaradhi',
#  'Sun, Hanfei',
#  'Guo, Fenfei',
#  'Ma, Zejun',
#  'Liang, Depeng',
#  'Sun, Jiasong',
#  'Kang, Pilsung',
#  'Yu, Mo',
#  'Reyle, U.',
#  'Wu, Chongruo',
#  'Lin, Yiou',
#  'Yun, Hyeongu',
#  'Lu, Yichao',
#  'Yun, Hyokun',
#  'Wu, Qingbo',
#  'Guo, Jiafeng',
#  'Chao, Wenhan',
#  'Jusoh, Shaidah',
#  'Wang, Feiran',
#  'Xu, Weidi',
#  'Zhang, Xihu',
#  'Jiang, Ke',
#  'Suárez, Ranyart R.',
#  'Gao, Qi',
#  'Chen, Guoguo',
#  'Huh, Hyun-Gue',
#  'Masse, A. Blondin',
#  'Paramesha, K',
#  'Sarkar, A. K.',
#  'Liu, Chunxi',
#  'Zhang, Mengdi',
#  'Hu, Minghao',
#  'McEvoy, C.',
#  'Halatsis, C.',
#  'Modaresi, Pashutan',
#  'Lenzo, K.',
#  'Bajaj, Goonmeet',
#  'Choi, Heeyoul',
#  'Shin, Jong-Hun',
#  'Lee, Hwaran',
#  'Zhou, Mantong',
#  'Wang, Haofen',
#  'Elayidom, M. Sudheep',
#  'You, Shaodi',
#  'Xu, Ruochen',
#  'Shen, Yikang',
#  'Wang, Yongkun',
#  'Cao, Rongyu',
#  'Lachkar, Abdelmonaime',
#  'Cheng, Dezhi',
#  'Hamid, Azzoune',
#  'Tovell, Ed',
#  'Ziser, Yftah',
#  'Suganthi, S.',
#  'Liu, Xunying',
#  'Ausloos, M.',
#  'Park, Noseong',
#  'Wu, Yu',
#  'Kolluru, S. K',
#  'Narayanan, Shrikanth. S.',
#  'Lande, D. V.',
#  'Agnes, F.',
#  'Lu, Chun-Ta',
#  'Hou, JianPeng',
#  'Shi, Dengliang',
#  'He, Wanjia',
#  'Shan, Chung-chieh',
#  'Zhao, Zhou',
#  'Kim, Byungsoo',
#  'Yamada, Ikuya',
#  'Tang, Cunchen',
#  'Nikolsky, Yuri',
#  'Zhang, Honglun',
#  'Li, Aodong',
#  'Hicham, Gueddah',
#  'Cooper-Leavitt, J.',
#  'Shin, Sanghyun',
#  'Li, Zuwei',
#  'Huang, Shu-Jian',
#  'Wang, Kaiye',
#  'Nongmeikapam, Kishorjit',
#  'Bagrow, J. P.',
#  'Kechedzhy, K. E.',
#  'Gerow, A.',
#  'Nonglenjaoba, Lairenlakpam',
#  'Dou, Zi-Yi',
#  'Tang, Buzhou',
#  'Xie, R. R.',
#  'Hess, M.',
#  'Li, Yuanxi',
#  'Lu, Le',
#  'Wang, Haoyu',
#  'Mohammed, N.',
#  'Ries, K.',
#  'Shah, Sanjiv. J.',
#  'Zheng, Suncong',
#  'Zhang, Saizheng',
#  'Shen, Haichen',
#  'Zhang, Zhengchen',
#  'Jordan, P. W.',
#  'Luo, Jiebo',
#  'Kottur, Satwik',
#  'Shen, Dinghan',
#  'Stavroula, Voyatzi',
#  'Kim, Sunghun',
#  'Park, Gwangbeen',
#  'Tan, Wang-Chiew',
#  'González-Gallardo, Carlos-Emiliano',
#  'Ramalingam, Dr. V.',
#  'Vahia, M. N.',
#  'Li, Shuangyin',
#  'Yu, Seunghak',
#  'Wang, Xinbing',
#  'Dai, Dengxin',
#  'Wang, Q. A.',
#  'Lahiri, Shibamouli',
#  'Zhu, Fengyun',
#  'Sandouk, Ubai',
#  'Huang, Yalou',
#  'Zhu, Zhenyao',
#  'Marcu, D.',
#  'Zhou, Chunting',
#  'Li, Jiefei',
#  "Mel'nyk, S. S.",
#  'Liu, Cong',
#  'Kim, Suyoun',
#  'Zhu, Zinan',
#  'Laura, Kallmeyer',
#  'Astrakhantsev, N.',
#  'Wu, Yi-Chiao',
#  'Song, Le',
#  'Zhang, Tianyang',
#  'Wang, Naiyan',
#  'Im, Jinbae',
#  'Wang, D. J.',
#  'Daelemans, W.',
#  'Gao, Sijia',
#  'Marquez, L.',
#  'Zhu, Tingshao',
#  'Zaremoodi, Poorya',
#  'Ramakrishnan, A. G.',
#  'Kim, K. H.',
#  'Hakkani-Tur, D.',
#  'Zhou, Dengyong',
#  'Maslov, V. P.',
#  'Zeng, Jiaan',
#  'Orphanos, G.',
#  'Bugarín, A.',
#  'Liu, Chunyang',
#  'Chen, Bikun',
#  'Gwon, Youngjune',
#  'Xiong, Caiming',
#  'Li, Xirong',
#  'Liu, Chundi',
#  'Wang, Haixun',
#  'Meteer, M.',
#  'Xu, Huazhe',
#  'Yeh, Jen-Yuan',
#  'Wang, Su',
#  'Yu, Yanshu',
#  'Bijal, Dalwadi',
#  'Chen, Yuanzhe',
#  'Zhou, Lianqiang',
#  'Yuan, Ye',
#  'El-Dosuky, M. A.',
#  'Huang, Ting-Hao Kenneth',
#  'Suslov, I. M.',
#  'Liu, Jialu',
#  'Hu, Ze',
#  'Ananthapadmanabha, T. V.',
#  'Huo, Zhao',
#  'Chen, Kuang-hua',
#  'Sanket, Suthar',
#  'Taylor, P.',
#  'Rose, Doori',
#  'Chen, Pin-Jung',
#  'Lin, ShouXun',
#  'Kiruthiga, M.',
#  'Wu, Jiadong',
#  'Kim, Gyuwan',
#  'Anantaram, C.',
#  'Ji, Shuiwang',
#  'Zhang, Weinan',
#  'Peral, J.',
#  'Rothenberger, T.',
#  'Sun, Shangdi',
#  'Tur, G.',
#  'Du, Shikang',
#  'Yang, Yinchong',
#  "Huang, Ting-Hao 'Kenneth'",
#  'Sachan, Mrinmaya',
#  'Lu, Bao-Liang',
#  'Hwang, Hsin-Te',
#  'Cho, KyungHyun',
#  'Martins, J. F.',
#  'Song, Li Kum',
#  'Paxton, A.',
#  'Ma, Xiaokong',
#  'Tseng, Bo-Hsiang',
#  'Chen, Yi-Pei',
#  'Zhang, Wei-Nan',
#  'Mao, Huizi',
#  'Taula, Thrivikrama',
#  'Burtsev, M. S.',
#  'Gonzalez-Agirre, A.',
#  'Singh, Mittul',
#  'Doria, F. A.',
#  'Spyropoulos, C. D.',
#  'Chen, Kan',
#  'Sonawane, Prof. Sheetal.',
#  'Li, Zhongliang',
#  'Guru, D. S.',
#  'Ruan, Guangchen',
#  'Chen, Yiran',
#  'de Oliveira, H. M.',
#  'Wang, Sun-Chong',
#  'Martinez, D.',
#  'Chen, Shizhe',
#  'Zhang, Zhengyou',
#  'Jin, Guantao',
#  'Chenthamarakshan, Vijil',
#  'Kuang, Da',
#  'Ma, Q.',
#  'Cao, Yunong',
#  'Li, Ge',
#  'Liu, Hanxiao',
#  'Ko, Byeongil',
#  'Kim, Youngsam',
#  'Palomar, M.',
#  'Padró, L.',
#  'Li, Wenpeng',
#  'Lai, Jianhuang',
#  'Yu, C.',
#  'Jurafsky, D.',
#  'Hu, Ronghang',
#  'Androutsopoulos, I.',
#  'Li, Chengkai',
#  'Zhou, Guorui',
#  'Zaidan, A. A',
#  'Agoramoorthy, G.',
#  'Prasad, Dr. T. V.',
#  'Deng, Li',
#  'Hsieh, Meng-Juei',
#  'Zha, Daochen',
#  'Kim, CzangYeob',
#  'Hu, Jiannan',
#  'Liao, Yi-Hsiu',
#  'Moussa, Assema',
#  'Lin, Hangyu',
#  'Lee, Sangho',
#  'Rodriguez, H.',
#  'Raj, P. C. Reghu',
#  'Zhang, Ruqing',
#  'Li, Yandong',
#  'Heo, Min-Oh',
#  'Azad, A. K. A.',
#  'Vasudevan, Gauthaman',
#  'Han, Xintong',
#  'Rigau, G.',
#  'Tang, Bo',
#  'Samer, Taalab',
#  'Leow, Wee-Kheng',
#  'Stolcke, A.',
#  'Hanani, Abualsoud',
#  'Lall, Brejesh',
#  'Zhao, Jialiang',
#  'Zhang, Shi-Xiong',
#  'Lupea, M.',
#  'Zhao, Jichang',
#  'Arregi, X.',
#  'Macdonell, S. G.',
#  'Mao, Kezhi',
#  'Goutham, Kushwanth N.',
#  'Hyon, Gyong-Il',
#  'Bin, Yi',
#  'Sarasola, K.',
#  'Abdelhak, Lakhouaja',
#  'Carbonell, N.',
#  'Orasan, C.',
#  'Baur, J.',
#  'Kuo, Hong-Kwang J.',
#  'Shivaswamy, Pannaga',
#  'Hwang, Kyuyeon',
#  'Huang, Shujian',
#  'Chang, Joon-Hyuk',
#  'Zhou, Mi',
#  'Kamisetty, Hetunandan',
#  'Zheng, Ronghuo',
#  'Nagao, M.',
#  'Kim, Hyon-Chol',
#  'Kang, Yongguo',
#  'Qiang, Jipeng',
#  'Abuhay, Tesfamariam M.',
#  'Maurel, D.',
#  'Rachad, T.',
#  'Senanayake, U.',
#  'Dhami, H. S.',
#  'Ghosh, Souvick',
#  'He, Yi',
#  'Miao, Yishu',
#  'Chen, Xinyun',
#  'van Klinken, G.',
#  'Zweig, G.',
#  'Mendes, R. Vilela',
#  'Chen, Changyou',
#  'Xie, Pengtao',
#  'Harris, K. D.',
#  'Yang, Jinbiao',
#  'Zhang, Ye',
#  'Wu, Chien-Sheng',
#  'Agrawal, Amritanshu',
#  'Li, Guangjian',
#  'Laprie, Y.',
#  'Lafferty, J.',
#  'Li, Xu',
#  'Kehat, Gitit',
#  'Wang, Tianlu',
#  'Liu, Peilei',
#  'Frank, M. R.',
#  'Min, K.',
#  'Tsalidis, C.',
#  'Walter, K.',
#  'Braichevsky, S.',
#  'Pak, Myong-Chol',
#  'Yu, Shuiyuan',
#  'Méndez-Cruz, Carlos-Francisco',
#  'Li, Caihua',
#  'Pramod, K. V.',
#  'Zhu, Danhao',
#  'Aduriz, I.',
#  'Rama, N.',
#  'Wiriyathammabhum, Peratham',
#  'Chen, Jitong',
#  'Li, Wu-Jun',
#  'Torfi, Amirsina',
#  'Liao, Han-Teng',
#  'Stent, A.',
#  'Liu, Zitao',
#  'Wu, Yajing',
#  'Sriram, V.',
#  'Munkhdalai, Tsendsuren',
#  'Han, Shuchu',
#  'Taylor, Jherez',
#  'Suleesathira, Raungrong',
#  'Rigo, M.',
#  'Brill, E.',
#  'Sun, Ming-Ting',
#  'Gu, Jiatao',
#  'Wan, Shengxian',
#  'Gao, Shuyang',
#  'Chen, Enhong',
#  'Calder, Jo',
#  'Connor, A. M.',
#  'Orsucci, F.',
#  'Pan, Sinno Jialin',
#  'He, Zhengqiu',
#  'Zhang, Zefeng',
#  'Sathyendra, Kanthashree Mysore',
#  'Zbilut, J. P.',
#  'Pires, A. J.',
#  'Dai, Haisheng',
#  'Alegria, I.',
#  'Shi, Tianze',
#  'Rumshisky, A.',
#  'Vidal, Maria-Esther',
#  'El-Beltagy, Samhaa R.',
#  'Arora, R.',
#  'Hussain, M. Asdaque',
#  'Ramgoolam, Sanjaye',
#  'Harti, M.',
#  'He, Tianxing',
#  'Wang, Yaxing',
#  'Xu, Yichong',
#  'Cao, Donglin',
#  'Liou, Yuan-ming',
#  'Han, Xu',
#  'Qin, Lianhui',
#  'Cheng, Pengxiang',
#  'Liu, Linqing',
#  'Luo, Bingfeng',
#  'Prasad, R.',
#  'Chen, Zhiqian',
#  'Wu, Xintao',
#  'Luan, Huanbo',
#  'Li, Huayu',
#  'Zhang, Aiqi',
#  'Haque, Md. Ansarul',
#  'Gao, Ji',
#  'Xu, Huijuan',
#  'Dale, R.',
#  'Hwang, Gene',
#  'Shin, Bonggun',
#  'Chuang, Kun-Ta',
#  'Kapetanios, E.',
#  'Sun, Shou-qian',
#  'Lee, Guang-He',
#  'Michel, Musiol',
#  'Vagelatos, A.',
#  'Wang, Xuguang',
#  'Kim, Taehwan',
#  'Narahari, Y.',
#  'Vaissiere, J.',
#  'Meng, Zhao',
#  'Choi, Sungwook',
#  'Cho, Pyeong Whan',
#  'Liu, Chia-Hsiang',
#  'Lee, Dongheui',
#  'Liang, Junying',
#  'Enguehard, C.',
#  'Li, Mantian',
#  'Li, Yaliang',
#  'Bao, Tingwen',
#  'Tsai, Yao-Hung Hubert',
#  'Ren, Yong',
#  'Jung, Namkyu',
#  'Kim, Gunhee',
#  'Vyas, O. P.',
#  'Wang, Hongcui',
#  'Zhou, Hai-Jun',
#  'Alanazi, Hamdan. O.',
#  'Wu, Yongjian',
#  'Wu, Dalei',
#  'Thain, Nithum',
#  'Yang, Haojin',
#  'Wang, Baiyang',
#  'Zhao, Haizhou',
#  'Zhao, Shenjian',
#  'Macbeth, Jamie',
#  'Lee, Jangho',
#  'Li, Zijian',
#  'Tian, Xu',
#  'Zhu, Zhaocheng',
#  'Li, Yi',
#  'Bose, Beepa',
#  'Zhang, Lanyun',
#  'Tang, Difei',
#  'Cao, Mengyun',
#  'Huang, Zi',
#  'Kang, Junlong',
#  'Chen, Welin',
#  'Jiang, Yong',
#  'Deegalla, S.',
#  'Sakkis, G.',
#  'Zhang, Ke-jun',
#  'Liu, Yong',
#  'Chiu, Yi-I',
#  'Jia, Jiyou',
#  'Asharaf, S.',
#  'Liu, Changfeng',
#  'Lu, Chang-Tien',
#  'Xu, Mingbin',
#  'Islam, S. M. Riazul',
#  'Barisevičius, G.',
#  'Karattil, Sajeer',
#  'Aphinyanaphongs, Yindalon',
#  'Rwebangira, Mugizi Robert',
#  'Sun, Zhiqing',
#  'Guo, Fangjian',
#  ...}

# %%
from metadata.metadata import ACL_metadata
acl = ACL_metadata()
df = acl.meta_df
known_m = acl.known_m
known_f = acl.known_f
# Out:
# Remember to use acl.modeling_files and modeling_df for topic modeling

# %%
df.columns
# Out:
# Index(['authors', 'genders', 'title', 'venue', 'year'], dtype='object')

# %%
import re
def is_initials(name, sp=","):
    
    fn = name.split(sp)
    if len(fn) < 2:
        return True
    fn = fn[1].strip()
    regex = re.compile(r"\w+\.", re.IGNORECASE)
    no_initials = regex.sub("", fn).strip()
    if len(no_initials) < 2:
        return True
    return False
        
def init_match(inits, name):
    inits = inits.replace("Dr.","")
    inits = inits.strip()
    if(len(inits) == 0):
        return 0
    name = name.strip()
    inits_split = inits.split(" ")
    name_split = name.split(" ")
    if len(inits_split) == len(name_split):
        match = True
        for idx, i in enumerate(inits_split):
            if i.strip()[0] != name_split[idx].strip()[0]:
                match = False
        if match == True:
            return 1 #confident match
    if inits[0] == name_split[0]:
        return 2 # maybe match
    inits_set = set()
    name_set = set()
    for letter in inits:
        if letter.isupper():
            inits_set.add(letter)
    for letter in name_set:
        if letter.isupper():
            name_set.add(letter)
    if inits_set == name_set:
        return 1 # confident match
    for letter in inits_set:
        if letter in name_set:
            return 3 # maybee
    return 0 #no match

from collections import defaultdict
male_last_names = defaultdict(list)
for name in known_m:
    if len(name.split(",")) != 2:
        continue
    last, first = name.split(",")
    male_last_names[last].append(first)
    
female_last_names = defaultdict(list)
for name in known_f:
    if len(name.split(",")) != 2:
        continue
    last, first = name.split(",")
    female_last_names[last].append(first)

def best_match(name):
    if len(name.split(",")) != 2:
        return (None, None)
    last, first = name.split(",")
    m = last in male_last_names
    f = last in female_last_names
    if m and not f:
        names = male_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                return (last + "," + n, Gender.male)
       
    if f and not m:
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if mtch != 0:
                return (last + "," + n, Gender.male)
    if f and m:
        
        match_f = 0
        match_m = 0
        names = male_last_names[last]
        best_match = (None, None)
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_m):
                match_m = mtch
                best_match = (last + ", " + n, Gender.male)
        names = female_last_names[last]
        for n in names:
            mtch = init_match(first, n)
            if(mtch > match_f):
                match_f = mtch
                if mtch > match_m:
                    best_match = (last + ", " + n, Gender.female)
        if match_f > match_m:
            return best_match
        if match_m > match_f:
            return best_match
    return (None, None)


c=['authors', 'genders', 'title', 'venue', 'year']
gender_df = pd.DataFrame(columns=c)
k = 0
for row in df.iterrows():
    new_entry = dict()
    for col in ["venue", "title", "year"]:
        new_entry[col] = row[1][col]
    new_entry["id"] = row[1].name
    authors = row[1]["authors"]
    genders = []
    correct_authors = []
    for a in authors:
        if is_initials(a,","):
            #print(a)
            #print(best_match(a))
            best_m, g = best_match(a)
            if best_m != None:
                correct_authors.append(best_m)
                genders.append(g)
                k += 1
                continue
                #print(a, best_m)
           
        correct_authors.append(a)
        if(a in known_m):
            genders.append(Gender.male)
        elif a in known_f:
            genders.append(Gender.female)
        else:
            genders.append(Gender.unknown)
    new_entry["authors"] = correct_authors
    new_entry["genders"] = genders
    gender_df = gender_df.append(new_entry, ignore_index=True)
gender_df.set_index("id")
print(k)
# Out:
# 88

# %%
my_new_unk = dict()
all_auths = set()
for row in gender_df.iterrows():
    genders = row[1]["genders"]
    authors = row[1]["authors"]
    paper = row[1]["title"]
    for i,g in enumerate(genders):
        if g == Gender.unknown:
            my_new_unk[authors[i]] = paper
    for a in authors:
        all_auths.add(a)

# %%
len(my_new_unk)
# Out:
# 973

# %%
len(acl.unk)
# Out:
# 1003

# %%
my_new_unk = dict()
all_auths = set()
for row in acl.meta_df.iterrows():
    genders = row[1]["genders"]
    authors = row[1]["authors"]
    paper = row[1]["title"]
    for i,g in enumerate(genders):
        if g == Gender.unknown:
            my_new_unk[authors[i]] = paper
    for a in authors:
        all_auths.add(a)

# %%
fd.save_pickle(gender_df,"acldf")

# %%
c=['authors', 'genders', 'title', 'venue', 'year']
gender_df = pd.DataFrame(columns=c)
k = 0
for row in df.iterrows():
    new_entry = dict()
    for col in ["venue", "title", "year"]:
        new_entry[col] = row[1][col]
    new_entry["id"] = row[1].name
    authors = row[1]["authors"]
    genders = []
    correct_authors = []
    for a in authors:
        correct_authors.append(a)
        if(a in known_m):
            genders.append(Gender.male)
        elif a in known_f:
            genders.append(Gender.female)
        else:
            genders.append(Gender.unknown)
    new_entry["authors"] = correct_authors
    new_entry["genders"] = genders
    gender_df = gender_df.append(new_entry, ignore_index=True)
gender_df.set_index("id")
# Out:
#                                                     authors  \
# id
# E03-1001                                    [Oard,Douglasw]
# E03-1002                                 [Henderson,Jamesb]
# E03-1003                  [Burstein,Jill, Wolska,Magdalena]
# E03-1004          [Cmejrek,Martin, Curin,Jan, Havelka,Jiri]
# E03-1005                                         [Bod,Rens]
# E03-1006  [Smets,Martine, Gamon,Michael, Corstonoliver,S...
# E03-1007                      [Ueffing,Nicola, Ney,Hermann]
# E03-1008  [Steedman,Mark, Osborne,Miles, Sarkar,Anoop, C...
# E03-1009                                  [Clark,Alexander]
# E03-1010  [Yasuda,Keiji, Sugaya,Fumiaki, Takezawa,Toshiy...
# E03-1011  [Dingli,Alexiei, Ciravegna,Fabio, Guthrie,Davi...
# E03-1012  [Alexin,Zoltan, Gyimothy,Tibor, Hatvani,Csaba,...
# E03-1013       [Hosaka,Junko, Koh,Judice, Konagaya,Akihiko]
# E03-1014                   [Zabokrtsky,Zdenek, Smrz,Otakar]
# E03-1015                                  [Poibeau,Thierry]
# E03-1017                                   [Horacek,Helmut]
# E03-1018                [Bentivogli,Luisa, Pianta,Emanuele]
# E03-1019                                       [Piwek,Paul]
# E03-1020                     [Dorow,Beate, Widdows,Dominic]
# E03-1021  [Sripada,Somayajulug, Reiter,Ehud, Hunter,Jim,...
# E03-1022        [Nerima,Luka, Seretan,Violeta, Wehrli,Eric]
# E03-1023  [Utsuro,Takehito, Horiuchi,Takashi, Hamamoto,T...
# E03-1024  [Koller,Alexander, Niehren,Joachim, Thater,Ste...
# E03-1025                                    [Preiss,Judita]
# E03-1026                                   [Tiedemann,Jorg]
# E03-1027                      [Erk,Katrin, Niehren,Joachim]
# E03-1028                                      [Penn,Gerald]
# E03-1029   [Imamura,Kenji, Sumita,Eiichiro, Matsumoto,Yuji]
# E03-1030                  [Gardent,Claire, Kallmeyer,Laura]
# E03-1031                                    [Ylijyra,Anssi]
# ...                                                     ...
# W14-3912  [King,Levi, Baucom,Eric, Gilmanov,Timur, Kuble...
# W14-3913                                   [Carpuat,Marine]
# W14-3914  [Bali,Kalika, Sharma,Jatin, Choudhury,Monojit,...
# W14-3915  [Barman,Utsab, Wagner,Joachim, Chrupala,Grzego...
# W14-3916                                 [Shrestha,Prajwol]
# W14-3917                      [Bar,Kfir, Dershowitz,Nachum]
# W14-4101                                      [Wise,Alyssa]
# W14-4102  [Sinha,Tanmay, Jermann,Patrick, Li,Nan, Dillen...
# W14-4103       [Moon,Seungwhan, Potdar,Saloni, Martin,Lara]
# W14-4104            [Yang,Diyi, Wen,Miaomiao, Rose,Carolyn]
# W14-4105                             [Elouazizi,Noureddine]
# W14-4106                                  [Jermann,Patrick]
# W14-4107                     [Rose,Carolyn, Siemens,George]
# W14-4108  [Sinha,Tanmay, Li,Nan, Jermann,Patrick, Dillen...
# W14-4109                     [Sharkey,Mike, Sanders,Robert]
# W14-4110  [Amnueypornsakul,Bussaba, Bhat,Suma, Chinprutt...
# W14-4111  [Kloft,Marius, Stiehler,Felix, Zheng,Zhilin, P...
# W14-4201                                     [Habash,Nizar]
# W14-4202  [Kanayama,Hiroshi, Park,Youngja, Tsuboi,Yuta, ...
# W14-4203  [Agic,Zeljko, Agic,Zeljko, Tiedemann,Jorg, Mer...
# W14-4204            [Maier,Wolfgang, Gomezrodriguez,Carlos]
# W14-4205                                     [Abbas,Qaiser]
# W14-4206  [Bhat,Riyazahmad, Jain,Naman, Vaidya,Ashwini, ...
# W14-4207                     [Nouri,Javad, Yangarber,Roman]
# W14-4208                                      [Petrov,Slav]
# W14-4209  [Miyazaki,Taro, Kato,Naoto, Inoue,Seiki, Umeda...
# W14-4210                    [Popovic,Maja, Ljubesic,Nikola]
# W14-4211  [Singla,Karan, Singh,Anupam, Shastri,Nishkarsh...
# W14-4212   [Kubon,Vladislav, Kubon,Vladislav, Vicic,Jernej]
# W14-4213       [Aminian,Maryam, Ghoneim,Mahmoud, Diab,Mona]
#
#                                                     genders  \
# id
# E03-1001                                      [Gender.male]
# E03-1002                                      [Gender.male]
# E03-1003                     [Gender.female, Gender.female]
# E03-1004            [Gender.male, Gender.male, Gender.male]
# E03-1005                                      [Gender.male]
# E03-1006  [Gender.female, Gender.male, Gender.male, Gend...
# E03-1007                       [Gender.female, Gender.male]
# E03-1008  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1009                                      [Gender.male]
# E03-1010  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1011  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1012  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1013        [Gender.female, Gender.female, Gender.male]
# E03-1014                         [Gender.male, Gender.male]
# E03-1015                                      [Gender.male]
# E03-1017                                      [Gender.male]
# E03-1018                       [Gender.female, Gender.male]
# E03-1019                                      [Gender.male]
# E03-1020                       [Gender.female, Gender.male]
# E03-1021  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1022          [Gender.male, Gender.female, Gender.male]
# E03-1023  [Gender.male, Gender.male, Gender.male, Gender...
# E03-1024            [Gender.male, Gender.male, Gender.male]
# E03-1025                                    [Gender.female]
# E03-1026                                      [Gender.male]
# E03-1027                       [Gender.female, Gender.male]
# E03-1028                                      [Gender.male]
# E03-1029            [Gender.male, Gender.male, Gender.male]
# E03-1030                     [Gender.female, Gender.female]
# E03-1031                                      [Gender.male]
# ...                                                     ...
# W14-3912  [Gender.male, Gender.male, Gender.male, Gender...
# W14-3913                                    [Gender.female]
# W14-3914  [Gender.female, Gender.male, Gender.male, Gend...
# W14-3915  [Gender.male, Gender.male, Gender.male, Gender...
# W14-3916                                      [Gender.male]
# W14-3917                         [Gender.male, Gender.male]
# W14-4101                                    [Gender.female]
# W14-4102  [Gender.male, Gender.male, Gender.unknown, Gen...
# W14-4103     [Gender.unknown, Gender.female, Gender.female]
# W14-4104      [Gender.female, Gender.female, Gender.female]
# W14-4105                                      [Gender.male]
# W14-4106                                      [Gender.male]
# W14-4107                       [Gender.female, Gender.male]
# W14-4108  [Gender.male, Gender.unknown, Gender.male, Gen...
# W14-4109                         [Gender.male, Gender.male]
# W14-4110        [Gender.female, Gender.female, Gender.male]
# W14-4111  [Gender.male, Gender.male, Gender.male, Gender...
# W14-4201                                      [Gender.male]
# W14-4202  [Gender.male, Gender.female, Gender.male, Gend...
# W14-4203  [Gender.male, Gender.male, Gender.male, Gender...
# W14-4204                         [Gender.male, Gender.male]
# W14-4205                                      [Gender.male]
# W14-4206  [Gender.male, Gender.male, Gender.female, Gend...
# W14-4207                         [Gender.male, Gender.male]
# W14-4208                                      [Gender.male]
# W14-4209  [Gender.male, Gender.male, Gender.male, Gender...
# W14-4210                       [Gender.female, Gender.male]
# W14-4211  [Gender.male, Gender.male, Gender.male, Gender...
# W14-4212            [Gender.male, Gender.male, Gender.male]
# W14-4213        [Gender.female, Gender.male, Gender.female]
#
#                                                       title  \
# id
# E03-1001  Multilingual Access To Large Spoken Archives (...
# E03-1002  Neural Network Probability Estimation For Broa...
# E03-1003  Toward Evaluation Of Writing Style: Overly Rep...
# E03-1004  Czech-English Dependency Tree-Based Machine Tr...
# E03-1005     An Efficient Implementation Of A New DOP Model
# E03-1006  French Amalgam: A Quick Adaptation Of A Senten...
# E03-1007  Using POS Information For SMT Into Morphologic...
# E03-1008  Bootstrapping Statistical Parsers From Small D...
# E03-1009  Combining Distributional And Morphological Inf...
# E03-1010  Automatic Evaluation For A Palpable Measure Of...
# E03-1011  Mining Web Sites Using Unsupervised Adaptive I...
# E03-1012                Manually Annotated Hungarian Corpus
# E03-1013  Effect Of Utilizing Terminology On Extraction ...
# E03-1014  Arabic Syntactic Trees: From Constituency To D...
# E03-1015  The Multilingual Named Entity Recognition Fram...
# E03-1017  A Best-First Search Algorithm For Generating R...
# E03-1018  Beyond Lexical Units: Enriching WordNets With ...
# E03-1019  A Flexible Pragmatics-Driven Language Generato...
# E03-1020            Discovering Corpus-Specific Word Senses
# E03-1021              Summarizing Neonatal Time Series Data
# E03-1022  Creating A Multilingual Collocations Dictionar...
# E03-1023  Effect Of Cross-Language IR In Bilingual Lexic...
# E03-1024  Underspecification Formalisms: Hole Semantics ...
# E03-1025     Using Grammatical Relations To Compare Parsers
# E03-1026                 Combining Clues For Word Alignment
# E03-1027  Well-Nested Parallelism Constraints For Ellips...
# E03-1028   AVM Description Compilation Using Types As Modes
# E03-1029  Automatic Construction Of Machine Translation ...
# E03-1030                     Semantic Construction In F-TAG
# E03-1031  Describing Syntax With Star-Free Regular Expre...
# ...                                                     ...
# W14-3912  The IUCL+ System: Word-Level Language Identifi...
# W14-3913  Mixed Language and Code-Switching in the Canad...
# W14-3914  I am borrowing ya mixing ? An Analysis of Engl...
# W14-3915  DCU-UVT: Word-Level Language Classification wi...
# W14-3916  Incremental N-gram Approach for Language Ident...
# W14-3917  The Tel Aviv University System for the Code-Sw...
# W14-4101  Keynote: Data Archeology: A theory informed ap...
# W14-4102  Your click decides your fate: Inferring Inform...
# W14-4103  Identifying Student Leaders from MOOC Discussi...
# W14-4104  Towards Identifying the Resolvability of Threa...
# W14-4105  Point-of-View Mining and Cognitive Presence in...
# W14-4106  Keynote Talk: Analytics: climbing up the ladde...
# W14-4107  Shared Task on Prediction of Dropout Over Time...
# W14-4108  Capturing attrition intensifying structural tr...
# W14-4109            A Process for Predicting MOOC Attrition
# W14-4110  Predicting Attrition Along the Way: The UIUC M...
# W14-4111  Predicting MOOC Dropout over Weeks Using Machi...
# W14-4201  INVITED TALK 1: Computational Processing of Ar...
# W14-4202  Learning from a Neighbor: Adapting a Japanese ...
# W14-4203  Cross-lingual Dependency Parsing of Related La...
# W14-4204  Language variety identification in Spanish tweets
# W14-4205  Exploiting Language Variants Via Grammar Parsi...
# W14-4206     Adapting Predicate Frames for Urdu PropBanking
# W14-4207  Measuring Language Closeness by Modeling Regul...
# W14-4208  INVITED TALK 2: Towards Universal Syntactic Pr...
# W14-4209  Proper Name Machine Translation from Japanese ...
# W14-4210  Exploring cross-language statistical machine t...
# W14-4211  Exploring System Combination approaches for In...
# W14-4212  A Comparison of MT Methods for Closely Related...
# W14-4213  Handling OOV Words in Dialectal Arabic to Engl...
#
#                                                       venue  year
# id
# E03-1001                                               EACL  2003
# E03-1002                                               EACL  2003
# E03-1003                                               EACL  2003
# E03-1004                                               EACL  2003
# E03-1005                                               EACL  2003
# E03-1006                                               EACL  2003
# E03-1007                                               EACL  2003
# E03-1008                                               EACL  2003
# E03-1009                                               EACL  2003
# E03-1010                                               EACL  2003
# E03-1011                                               EACL  2003
# E03-1012                                               EACL  2003
# E03-1013                                               EACL  2003
# E03-1014                                               EACL  2003
# E03-1015                                               EACL  2003
# E03-1017                                               EACL  2003
# E03-1018                                               EACL  2003
# E03-1019                                               EACL  2003
# E03-1020                                               EACL  2003
# E03-1021                                               EACL  2003
# E03-1022                                               EACL  2003
# E03-1023                                               EACL  2003
# E03-1024                                               EACL  2003
# E03-1025                                               EACL  2003
# E03-1026                                               EACL  2003
# E03-1027                                               EACL  2003
# E03-1028                                               EACL  2003
# E03-1029                                               EACL  2003
# E03-1030                                               EACL  2003
# E03-1031                                               EACL  2003
# ...                                                     ...   ...
# W14-3912  Workshop on Computational Approaches to Code S...  2014
# W14-3913  Workshop on Computational Approaches to Code S...  2014
# W14-3914  Workshop on Computational Approaches to Code S...  2014
# W14-3915  Workshop on Computational Approaches to Code S...  2014
# W14-3916  Workshop on Computational Approaches to Code S...  2014
# W14-3917  Workshop on Computational Approaches to Code S...  2014
# W14-4101  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4102  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4103  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4104  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4105  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4106  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4107  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4108  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4109  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4110  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4111  Workshop on Analysis of Large Scale Social Int...  2014
# W14-4201                                       LT4CloseLang  2014
# W14-4202                                       LT4CloseLang  2014
# W14-4203                                       LT4CloseLang  2014
# W14-4204                                       LT4CloseLang  2014
# W14-4205                                       LT4CloseLang  2014
# W14-4206                                       LT4CloseLang  2014
# W14-4207                                       LT4CloseLang  2014
# W14-4208                                       LT4CloseLang  2014
# W14-4209                                       LT4CloseLang  2014
# W14-4210                                       LT4CloseLang  2014
# W14-4211                                       LT4CloseLang  2014
# W14-4212                                       LT4CloseLang  2014
# W14-4213                                       LT4CloseLang  2014
#
# [23766 rows x 5 columns]

# %%
my_new_unk = dict()
all_auths = set()
for row in acl.meta_df.iterrows():
    genders = row[1]["genders"]
    authors = row[1]["authors"]
    paper = row[1]["title"]
    for i,g in enumerate(genders):
        if g == Gender.unknown:
            my_new_unk[authors[i]] = paper
    for a in authors:
        all_auths.add(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-afca875e7c63> in <module>()
#       1 my_new_unk = dict()
#       2 all_auths = set()
# ----> 3 for row in acl.meta_df.iterrows():
#       4     genders = row[1]["genders"]
#       5     authors = row[1]["authors"]
#
# NameError: name 'acl' is not defined

# %%
gender_df
# Out:
#                                                  authors  \
# 0                                        [Oard,Douglasw]
# 1                                     [Henderson,Jamesb]
# 2                      [Burstein,Jill, Wolska,Magdalena]
# 3              [Cmejrek,Martin, Curin,Jan, Havelka,Jiri]
# 4                                             [Bod,Rens]
# 5      [Smets,Martine, Gamon,Michael, Corstonoliver,S...
# 6                          [Ueffing,Nicola, Ney,Hermann]
# 7      [Steedman,Mark, Osborne,Miles, Sarkar,Anoop, C...
# 8                                      [Clark,Alexander]
# 9      [Yasuda,Keiji, Sugaya,Fumiaki, Takezawa,Toshiy...
# 10     [Dingli,Alexiei, Ciravegna,Fabio, Guthrie,Davi...
# 11     [Alexin,Zoltan, Gyimothy,Tibor, Hatvani,Csaba,...
# 12          [Hosaka,Junko, Koh,Judice, Konagaya,Akihiko]
# 13                      [Zabokrtsky,Zdenek, Smrz,Otakar]
# 14                                     [Poibeau,Thierry]
# 15                                      [Horacek,Helmut]
# 16                   [Bentivogli,Luisa, Pianta,Emanuele]
# 17                                          [Piwek,Paul]
# 18                        [Dorow,Beate, Widdows,Dominic]
# 19     [Sripada,Somayajulug, Reiter,Ehud, Hunter,Jim,...
# 20           [Nerima,Luka, Seretan,Violeta, Wehrli,Eric]
# 21     [Utsuro,Takehito, Horiuchi,Takashi, Hamamoto,T...
# 22     [Koller,Alexander, Niehren,Joachim, Thater,Ste...
# 23                                       [Preiss,Judita]
# 24                                      [Tiedemann,Jorg]
# 25                         [Erk,Katrin, Niehren,Joachim]
# 26                                         [Penn,Gerald]
# 27      [Imamura,Kenji, Sumita,Eiichiro, Matsumoto,Yuji]
# 28                     [Gardent,Claire, Kallmeyer,Laura]
# 29                                       [Ylijyra,Anssi]
# ...                                                  ...
# 23736  [King,Levi, Baucom,Eric, Gilmanov,Timur, Kuble...
# 23737                                   [Carpuat,Marine]
# 23738  [Bali,Kalika, Sharma,Jatin, Choudhury,Monojit,...
# 23739  [Barman,Utsab, Wagner,Joachim, Chrupala,Grzego...
# 23740                                 [Shrestha,Prajwol]
# 23741                      [Bar,Kfir, Dershowitz,Nachum]
# 23742                                      [Wise,Alyssa]
# 23743  [Sinha,Tanmay, Jermann,Patrick, Li,Nan, Dillen...
# 23744       [Moon,Seungwhan, Potdar,Saloni, Martin,Lara]
# 23745            [Yang,Diyi, Wen,Miaomiao, Rose,Carolyn]
# 23746                             [Elouazizi,Noureddine]
# 23747                                  [Jermann,Patrick]
# 23748                     [Rose,Carolyn, Siemens,George]
# 23749  [Sinha,Tanmay, Li,Nan, Jermann,Patrick, Dillen...
# 23750                     [Sharkey,Mike, Sanders,Robert]
# 23751  [Amnueypornsakul,Bussaba, Bhat,Suma, Chinprutt...
# 23752  [Kloft,Marius, Stiehler,Felix, Zheng,Zhilin, P...
# 23753                                     [Habash,Nizar]
# 23754  [Kanayama,Hiroshi, Park,Youngja, Tsuboi,Yuta, ...
# 23755  [Agic,Zeljko, Agic,Zeljko, Tiedemann,Jorg, Mer...
# 23756            [Maier,Wolfgang, Gomezrodriguez,Carlos]
# 23757                                     [Abbas,Qaiser]
# 23758  [Bhat,Riyazahmad, Jain,Naman, Vaidya,Ashwini, ...
# 23759                     [Nouri,Javad, Yangarber,Roman]
# 23760                                      [Petrov,Slav]
# 23761  [Miyazaki,Taro, Kato,Naoto, Inoue,Seiki, Umeda...
# 23762                    [Popovic,Maja, Ljubesic,Nikola]
# 23763  [Singla,Karan, Singh,Anupam, Shastri,Nishkarsh...
# 23764   [Kubon,Vladislav, Kubon,Vladislav, Vicic,Jernej]
# 23765       [Aminian,Maryam, Ghoneim,Mahmoud, Diab,Mona]
#
#                                                  genders  \
# 0                                          [Gender.male]
# 1                                          [Gender.male]
# 2                         [Gender.female, Gender.female]
# 3                [Gender.male, Gender.male, Gender.male]
# 4                                          [Gender.male]
# 5      [Gender.female, Gender.male, Gender.male, Gend...
# 6                           [Gender.female, Gender.male]
# 7      [Gender.male, Gender.male, Gender.male, Gender...
# 8                                          [Gender.male]
# 9      [Gender.male, Gender.male, Gender.male, Gender...
# 10     [Gender.male, Gender.male, Gender.male, Gender...
# 11     [Gender.male, Gender.male, Gender.male, Gender...
# 12           [Gender.female, Gender.female, Gender.male]
# 13                            [Gender.male, Gender.male]
# 14                                         [Gender.male]
# 15                                         [Gender.male]
# 16                          [Gender.female, Gender.male]
# 17                                         [Gender.male]
# 18                          [Gender.female, Gender.male]
# 19     [Gender.male, Gender.male, Gender.male, Gender...
# 20             [Gender.male, Gender.female, Gender.male]
# 21     [Gender.male, Gender.male, Gender.male, Gender...
# 22               [Gender.male, Gender.male, Gender.male]
# 23                                       [Gender.female]
# 24                                         [Gender.male]
# 25                          [Gender.female, Gender.male]
# 26                                         [Gender.male]
# 27               [Gender.male, Gender.male, Gender.male]
# 28                        [Gender.female, Gender.female]
# 29                                         [Gender.male]
# ...                                                  ...
# 23736  [Gender.male, Gender.male, Gender.male, Gender...
# 23737                                    [Gender.female]
# 23738  [Gender.female, Gender.male, Gender.male, Gend...
# 23739  [Gender.male, Gender.male, Gender.male, Gender...
# 23740                                      [Gender.male]
# 23741                         [Gender.male, Gender.male]
# 23742                                    [Gender.female]
# 23743  [Gender.male, Gender.male, Gender.unknown, Gen...
# 23744     [Gender.unknown, Gender.female, Gender.female]
# 23745      [Gender.female, Gender.female, Gender.female]
# 23746                                      [Gender.male]
# 23747                                      [Gender.male]
# 23748                       [Gender.female, Gender.male]
# 23749  [Gender.male, Gender.unknown, Gender.male, Gen...
# 23750                         [Gender.male, Gender.male]
# 23751        [Gender.female, Gender.female, Gender.male]
# 23752  [Gender.male, Gender.male, Gender.male, Gender...
# 23753                                      [Gender.male]
# 23754  [Gender.male, Gender.female, Gender.male, Gend...
# 23755  [Gender.male, Gender.male, Gender.male, Gender...
# 23756                         [Gender.male, Gender.male]
# 23757                                      [Gender.male]
# 23758  [Gender.male, Gender.male, Gender.female, Gend...
# 23759                         [Gender.male, Gender.male]
# 23760                                      [Gender.male]
# 23761  [Gender.male, Gender.male, Gender.male, Gender...
# 23762                       [Gender.female, Gender.male]
# 23763  [Gender.male, Gender.male, Gender.male, Gender...
# 23764            [Gender.male, Gender.male, Gender.male]
# 23765        [Gender.female, Gender.male, Gender.female]
#
#                                                    title  \
# 0      Multilingual Access To Large Spoken Archives (...
# 1      Neural Network Probability Estimation For Broa...
# 2      Toward Evaluation Of Writing Style: Overly Rep...
# 3      Czech-English Dependency Tree-Based Machine Tr...
# 4         An Efficient Implementation Of A New DOP Model
# 5      French Amalgam: A Quick Adaptation Of A Senten...
# 6      Using POS Information For SMT Into Morphologic...
# 7      Bootstrapping Statistical Parsers From Small D...
# 8      Combining Distributional And Morphological Inf...
# 9      Automatic Evaluation For A Palpable Measure Of...
# 10     Mining Web Sites Using Unsupervised Adaptive I...
# 11                   Manually Annotated Hungarian Corpus
# 12     Effect Of Utilizing Terminology On Extraction ...
# 13     Arabic Syntactic Trees: From Constituency To D...
# 14     The Multilingual Named Entity Recognition Fram...
# 15     A Best-First Search Algorithm For Generating R...
# 16     Beyond Lexical Units: Enriching WordNets With ...
# 17     A Flexible Pragmatics-Driven Language Generato...
# 18               Discovering Corpus-Specific Word Senses
# 19                 Summarizing Neonatal Time Series Data
# 20     Creating A Multilingual Collocations Dictionar...
# 21     Effect Of Cross-Language IR In Bilingual Lexic...
# 22     Underspecification Formalisms: Hole Semantics ...
# 23        Using Grammatical Relations To Compare Parsers
# 24                    Combining Clues For Word Alignment
# 25     Well-Nested Parallelism Constraints For Ellips...
# 26      AVM Description Compilation Using Types As Modes
# 27     Automatic Construction Of Machine Translation ...
# 28                        Semantic Construction In F-TAG
# 29     Describing Syntax With Star-Free Regular Expre...
# ...                                                  ...
# 23736  The IUCL+ System: Word-Level Language Identifi...
# 23737  Mixed Language and Code-Switching in the Canad...
# 23738  I am borrowing ya mixing ? An Analysis of Engl...
# 23739  DCU-UVT: Word-Level Language Classification wi...
# 23740  Incremental N-gram Approach for Language Ident...
# 23741  The Tel Aviv University System for the Code-Sw...
# 23742  Keynote: Data Archeology: A theory informed ap...
# 23743  Your click decides your fate: Inferring Inform...
# 23744  Identifying Student Leaders from MOOC Discussi...
# 23745  Towards Identifying the Resolvability of Threa...
# 23746  Point-of-View Mining and Cognitive Presence in...
# 23747  Keynote Talk: Analytics: climbing up the ladde...
# 23748  Shared Task on Prediction of Dropout Over Time...
# 23749  Capturing attrition intensifying structural tr...
# 23750            A Process for Predicting MOOC Attrition
# 23751  Predicting Attrition Along the Way: The UIUC M...
# 23752  Predicting MOOC Dropout over Weeks Using Machi...
# 23753  INVITED TALK 1: Computational Processing of Ar...
# 23754  Learning from a Neighbor: Adapting a Japanese ...
# 23755  Cross-lingual Dependency Parsing of Related La...
# 23756  Language variety identification in Spanish tweets
# 23757  Exploiting Language Variants Via Grammar Parsi...
# 23758     Adapting Predicate Frames for Urdu PropBanking
# 23759  Measuring Language Closeness by Modeling Regul...
# 23760  INVITED TALK 2: Towards Universal Syntactic Pr...
# 23761  Proper Name Machine Translation from Japanese ...
# 23762  Exploring cross-language statistical machine t...
# 23763  Exploring System Combination approaches for In...
# 23764  A Comparison of MT Methods for Closely Related...
# 23765  Handling OOV Words in Dialectal Arabic to Engl...
#
#                                                    venue  year        id
# 0                                                   EACL  2003  E03-1001
# 1                                                   EACL  2003  E03-1002
# 2                                                   EACL  2003  E03-1003
# 3                                                   EACL  2003  E03-1004
# 4                                                   EACL  2003  E03-1005
# 5                                                   EACL  2003  E03-1006
# 6                                                   EACL  2003  E03-1007
# 7                                                   EACL  2003  E03-1008
# 8                                                   EACL  2003  E03-1009
# 9                                                   EACL  2003  E03-1010
# 10                                                  EACL  2003  E03-1011
# 11                                                  EACL  2003  E03-1012
# 12                                                  EACL  2003  E03-1013
# 13                                                  EACL  2003  E03-1014
# 14                                                  EACL  2003  E03-1015
# 15                                                  EACL  2003  E03-1017
# 16                                                  EACL  2003  E03-1018
# 17                                                  EACL  2003  E03-1019
# 18                                                  EACL  2003  E03-1020
# 19                                                  EACL  2003  E03-1021
# 20                                                  EACL  2003  E03-1022
# 21                                                  EACL  2003  E03-1023
# 22                                                  EACL  2003  E03-1024
# 23                                                  EACL  2003  E03-1025
# 24                                                  EACL  2003  E03-1026
# 25                                                  EACL  2003  E03-1027
# 26                                                  EACL  2003  E03-1028
# 27                                                  EACL  2003  E03-1029
# 28                                                  EACL  2003  E03-1030
# 29                                                  EACL  2003  E03-1031
# ...                                                  ...   ...       ...
# 23736  Workshop on Computational Approaches to Code S...  2014  W14-3912
# 23737  Workshop on Computational Approaches to Code S...  2014  W14-3913
# 23738  Workshop on Computational Approaches to Code S...  2014  W14-3914
# 23739  Workshop on Computational Approaches to Code S...  2014  W14-3915
# 23740  Workshop on Computational Approaches to Code S...  2014  W14-3916
# 23741  Workshop on Computational Approaches to Code S...  2014  W14-3917
# 23742  Workshop on Analysis of Large Scale Social Int...  2014  W14-4101
# 23743  Workshop on Analysis of Large Scale Social Int...  2014  W14-4102
# 23744  Workshop on Analysis of Large Scale Social Int...  2014  W14-4103
# 23745  Workshop on Analysis of Large Scale Social Int...  2014  W14-4104
# 23746  Workshop on Analysis of Large Scale Social Int...  2014  W14-4105
# 23747  Workshop on Analysis of Large Scale Social Int...  2014  W14-4106
# 23748  Workshop on Analysis of Large Scale Social Int...  2014  W14-4107
# 23749  Workshop on Analysis of Large Scale Social Int...  2014  W14-4108
# 23750  Workshop on Analysis of Large Scale Social Int...  2014  W14-4109
# 23751  Workshop on Analysis of Large Scale Social Int...  2014  W14-4110
# 23752  Workshop on Analysis of Large Scale Social Int...  2014  W14-4111
# 23753                                       LT4CloseLang  2014  W14-4201
# 23754                                       LT4CloseLang  2014  W14-4202
# 23755                                       LT4CloseLang  2014  W14-4203
# 23756                                       LT4CloseLang  2014  W14-4204
# 23757                                       LT4CloseLang  2014  W14-4205
# 23758                                       LT4CloseLang  2014  W14-4206
# 23759                                       LT4CloseLang  2014  W14-4207
# 23760                                       LT4CloseLang  2014  W14-4208
# 23761                                       LT4CloseLang  2014  W14-4209
# 23762                                       LT4CloseLang  2014  W14-4210
# 23763                                       LT4CloseLang  2014  W14-4211
# 23764                                       LT4CloseLang  2014  W14-4212
# 23765                                       LT4CloseLang  2014  W14-4213
#
# [23766 rows x 6 columns]

# %%
my_new_unk2 = my_new_unk
