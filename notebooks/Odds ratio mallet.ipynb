# %%
from gensim.models.ldamodel import LdaModel
from gensim.corpora import MmCorpus
from gensim.corpora import Dictionary
from collections import Counter
from numpy.random import seed
from collections import defaultdict
from metadata.metadata import ACL_metadata
from metadata import Gender
import matplotlib.pyplot as plt
import numpy as np
import logging
import gensim 
seed(1)
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO

# %%
model = gensim.models.wrappers.ldamallet.LdaMallet.load("../malltepy")
# Out:
# INFO:gensim.utils:loading LdaMallet object from ../malltepy
# INFO:gensim.utils:loaded ../malltepy

# %%
doc_topics = list(model.load_document_topics())

# %%
acl = ACL_metadata()
df = acl.meta_df

# %%
females_topics = []
females_topics_proportions = defaultdict(int) # P(topic|gender)'
males_topics_proportions = defaultdict(int)
fem_norm = 0 # normalizer
male_norm = 0
males_topics = []
for i, file in enumerate(acl.train_files):
    try:
        topics = doc_topics[i]
        gender = df.loc[acl.get_id(file)]["genders"][0] #first author
        if gender == Gender.female:
            for topic, p in topics:
                females_topics_proportions[topic] += p
            fem_norm +=1
        elif gender == Gender.male:
            for topic, p in topics:
                males_topics_proportions[topic] += p
            male_norm +=1
    except KeyError:
        pass

# %%
for idx in range(100):
    f = females_topics_proportions[idx] / fem_norm
    m = males_topics_proportions[idx] / male_norm
    odds = (f * (1-f)) / (m * (1-m))
    if odds > 1.5:
        print("Females are {0:.2f} more likeky than men to write about topic {1:d}".format(odds, idx))
        print("Most common words for this topic are:")
        for w,p in model.show_topic(idx,10):
            print(w,)
        print("-"*30)
        print("-"*30)
# Out:
# Females are 1.76 more likeky than men to write about topic 8
# Most common words for this topic are:
# essay
# genre
# response
# author
# native
# readability
# read
# write
# style
# grade
# ------------------------------
# ------------------------------
# Females are 2.43 more likeky than men to write about topic 12
# Most common words for this topic are:
# prosodic
# speaker
# repair
# utterance
# pitch
# pause
# accent
# turn
# boundary
# speak
# ------------------------------
# ------------------------------
# Females are 1.84 more likeky than men to write about topic 23
# Most common words for this topic are:
# expression
# mwe
# mwes
# multiword
# idiom
# light
# compositional
# idiomatic
# portuguese
# multiword_expression
# ------------------------------
# ------------------------------
# Females are 1.98 more likeky than men to write about topic 26
# Most common words for this topic are:
# plan
# action
# act
# goal
# speaker
# discourse
# utterance
# agent
# belief
# proposition
# ------------------------------
# ------------------------------
# Females are 1.63 more likeky than men to write about topic 27
# Most common words for this topic are:
# cue
# scope
# negation
# citation
# hedge
# scientific
# claim
# cite
# modality
# token
# ------------------------------
# ------------------------------
# Females are 1.58 more likeky than men to write about topic 39
# Most common words for this topic are:
# emotion
# post
# social
# email
# thread
# conversation
# gender
# comment
# blog
# discussion
# ------------------------------
# ------------------------------
# Females are 1.88 more likeky than men to write about topic 40
# Most common words for this topic are:
# discourse
# connective
# coherence
# rhetorical
# marker
# rst
# unit
# causal
# clause
# implicit
# ------------------------------
# ------------------------------
# Females are 1.89 more likeky than men to write about topic 41
# Most common words for this topic are:
# medical
# patient
# clinical
# disease
# drug
# health
# umls
# record
# biomedical
# medicine
# ------------------------------
# ------------------------------
# Females are 1.51 more likeky than men to write about topic 64
# Most common words for this topic are:
# verb
# subject
# object
# argument
# noun
# verbs
# construction
# obj
# verbal
# passive
# ------------------------------
# ------------------------------
# Females are 1.79 more likeky than men to write about topic 76
# Most common words for this topic are:
# annotation
# annotator
# annotate
# agreement
# scheme
# category
# inter
# label
# mark
# kappa
# ------------------------------
# ------------------------------
# Females are 1.69 more likeky than men to write about topic 80
# Most common words for this topic are:
# frame
# framenet
# verb
# role
# subcategorization
# verbnet
# element
# resource
# target
# lexicon
# ------------------------------
# ------------------------------
# Females are 1.94 more likeky than men to write about topic 82
# Most common words for this topic are:
# student
# tutor
# feedback
# learning
# learner
# nlp
# teacher
# tutorial
# exercise
# tutoring
# ------------------------------
# ------------------------------
# Females are 1.51 more likeky than men to write about topic 91
# Most common words for this topic are:
# summary
# summarization
# document
# content
# rouge
# topic
# multi
# length
# multi_document
# lin
# ------------------------------
# ------------------------------

# %%
for idx in range(100):
    f = females_topics_proportions[idx] / fem_norm
    m = males_topics_proportions[idx] / male_norm
    odds = (m * (1-m)) / (f * (1-f))
    if odds > 1.5:
        print("Males are {0:.2f} more likeky than females to write about topic {1:d}".format(odds, idx))
        print("Most common words for this topic are:")
        for w,p in model.show_topic(idx,10):
            print(w,)
        print("-"*30)
        print("-"*30)
# Out:
# Males are 1.55 more likeky than females to write about topic 20
# Most common words for this topic are:
# grammar
# parse
# parser
# category
# parsing
# chart
# ccg
# pars
# coverage
# ambiguity
# ------------------------------
# ------------------------------
# Males are 1.82 more likeky than females to write about topic 24
# Most common words for this topic are:
# grammar
# tree
# derivation
# free
# string
# context_free
# tag
# symbol
# terminal
# production
# ------------------------------
# ------------------------------
# Males are 1.58 more likeky than females to write about topic 33
# Most common words for this topic are:
# translation
# grammar
# span
# forest
# derivation
# string
# tree
# syntax
# synchronous
# terminal
# ------------------------------
# ------------------------------
# Males are 1.80 more likeky than females to write about topic 36
# Most common words for this topic are:
# weight
# parameter
# linear
# learning
# vector
# loss
# discriminative
# log
# perceptron
# update
# ------------------------------
# ------------------------------
# Males are 1.52 more likeky than females to write about topic 44
# Most common words for this topic are:
# dependency
# parser
# parse
# parsing
# head
# tree
# treebank
# nivre
# projective
# label
# ------------------------------
# ------------------------------
# Males are 2.16 more likeky than females to write about topic 49
# Most common words for this topic are:
# size
# memory
# prune
# speed
# length
# space
# cost
# index
# fast
# store
# ------------------------------
# ------------------------------
# Males are 1.68 more likeky than females to write about topic 50
# Most common words for this topic are:
# program
# grammar
# object
# node
# ion
# john
# frame
# network
# inference
# meaning
# ------------------------------
# ------------------------------
# Males are 1.85 more likeky than females to write about topic 51
# Most common words for this topic are:
# japanese
# japan
# expression
# accuracy
# noun
# dictionary
# tokyo
# kanji
# bunsetsu
# kyoto
# ------------------------------
# ------------------------------
# Males are 2.09 more likeky than females to write about topic 57
# Most common words for this topic are:
# finite
# transducer
# string
# finite_state
# regular
# symbol
# automaton
# transition
# weight
# grammar
# ------------------------------
# ------------------------------
# Males are 1.62 more likeky than females to write about topic 87
# Most common words for this topic are:
# logical
# logic
# interpretation
# formula
# predicate
# variable
# scope
# expression
# quantifier
# logical_form
# ------------------------------
# ------------------------------
# Males are 2.21 more likeky than females to write about topic 88
# Most common words for this topic are:
# stack
# action
# transition
# arc
# shift
# beam
# parsing
# parser
# reduce
# incremental
# ------------------------------
# ------------------------------
# Males are 1.52 more likeky than females to write about topic 92
# Most common words for this topic are:
# constraint
# solution
# local
# variable
# global
# solve
# optimal
# ilp
# linear
# straint
# ------------------------------
# ------------------------------
# Males are 1.54 more likeky than females to write about topic 98
# Most common words for this topic are:
# probability
# estimate
# gram
# parameter
# distribution
# entropy
# probabilistic
# maximum
# estimation
# sequence
# ------------------------------
# ------------------------------
